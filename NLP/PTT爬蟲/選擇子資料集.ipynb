# %%
import glob
fs = glob.glob("pttdata/*.json")
len(fs)
# Out:
# 128514

# %%
import random
rfs = random.sample(fs, k=20000)

# %%
rfs
# Out:
# ['pttdata/M.1567834091.A.400.json',
#  'pttdata/M.1563539850.A.4A1.json',
#  'pttdata/M.1566387417.A.67E.json',
#  'pttdata/M.1562209050.A.68E.json',
#  'pttdata/M.1565795849.A.7DA.json',
#  'pttdata/M.1567744333.A.7BA.json',
#  'pttdata/M.1562511825.A.ED0.json',
#  'pttdata/M.1564382025.A.BCB.json',
#  'pttdata/M.1562300693.A.0FB.json',
#  'pttdata/M.1562983975.A.DDE.json',
#  'pttdata/M.1563074849.A.468.json',
#  'pttdata/M.1563686960.A.36B.json',
#  'pttdata/M.1569912996.A.00B.json',
#  'pttdata/M.1568975730.A.E68.json',
#  'pttdata/M.1568094309.A.E24.json',
#  'pttdata/M.1569575443.A.4BF.json',
#  'pttdata/M.1568049977.A.752.json',
#  'pttdata/M.1568339490.A.0B7.json',
#  'pttdata/M.1570072730.A.E84.json',
#  'pttdata/M.1569151764.A.4D8.json',
#  'pttdata/M.1564913323.A.950.json',
#  'pttdata/M.1562341513.A.8C5.json',
#  'pttdata/M.1568548376.A.86F.json',
#  'pttdata/M.1564239863.A.954.json',
#  'pttdata/M.1562141952.A.38A.json',
#  'pttdata/M.1567107640.A.977.json',
# ...

# %%
import shutil
for r in rfs:
    rfn = r.replace("pttdata", "pttsmalldata", 1)
    shutil.copyfile(r, rfn)
