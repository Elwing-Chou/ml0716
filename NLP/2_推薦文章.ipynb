# %%
# 為了美觀 我把Future Warning關閉
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import glob
import json
import pandas as pd
# 拿取所有 *.json 檔案
fs = glob.glob("./pttsmalldata/*.json")
# 我們只取用 內文 標題 和 型態(問卦...等等)
# 但實際上我們只使用 內文 做訓練而已
contents = []
titles = []
types = []
for fn in fs:
    with open(fn, "r", encoding="utf-8") as f:
        data = json.load(f)
        contents.append(data["post_content"])
        titles.append(data["post_title"])
        types.append(data["post_type"])
# 準備成表格
df = pd.DataFrame({
    "type":types,
    "title":titles,
    "content":contents
}, columns=["type", "title", "content"])       
df
# Out:
#       type                   title  \
# 0       問卦     小北若去日本展店 會被唐吉一拳打死嗎?
# 1       新聞     自排入不分區立委？ 李昭平：吳敦義從沒
# 2       問卦       有沒有這波警察被桶覺青消失的八卦？
# 3       新聞    謝鑫佑被唬到大 小說寫覆鼎金多年後成預言
# 4       新聞      促韓國瑜辭職 高市藍綠議員爆肢體衝突
# 5       問卦               我不擔憂會相見恨晚
# 6       新聞    日本「最可愛女高校生」前10強出爐　網狂
# 7       新聞            京-台高鐵中國段 已開通
# 8       問卦     颱風沒來可喜可賀可是手伸不進品客罐子
# 9       問卦        習近平為什麼不讓中國變民主國家？
# 10      問卦             真正害了香港的人是誰？
# 11      問卦        小穹怎麼在上面>< (小穹陣線)
# 12      新聞         談到韓國瑜與侯友宜 黃暐瀚哽咽
# 13      爆卦   ㊣破解高鐵延伸(3)ＴＭＤ之台北州花蓮港廳
# 14      問卦         有沒有鴛鴦乾坤麻花鎖怎解的掛卦
# 15      問卦                  睡不著怎麼辦
# 16      問卦             方芮欣是不是檢舉達人？
# 17      問卦             妹子來我家住要注意什麼
# 18      問卦        月薪十萬 是不是也很難住臺北市？
# 19      問卦    有沒有Joeman破160萬訂閱的八卦？
# 20      問卦    228事件被一堆軍統臥底反串搞分化的八卦
# 21      問卦            去皇家俱樂部該注意什麼？
# 22      問卦               我484越來越邊緣
# 23      問卦         沒對外戰爭的獨裁國是不是穩了？
# 24      問卦            有沒有創意吸收水分的八卦
# 25      新聞      對戰蔡英文、韓國瑜 林濁水：柯文哲得
# 26      新聞        名DJ慘死 粉絲葬禮發狂開棺驗屍
# 27      問卦             有沒有極限體能王的八卦
# 28      問卦            這次還會出現歪腰郵筒嗎？
# 29      問卦               呆腦獸到底是三小？
# ...    ...                     ...
# 19970   問卦              大家都寫名字還是名子
# 19971   新聞      不捨勇警殉職!李來希怒揭原因嗆爆小英
# 19972   問卦           七天假很多人原本就沒放吧？
# 19973   問卦           為什麼客家小炒不叫客家大炒
# 19974   問卦             明天過後八卦板會怎樣?
# 19975   新聞     貧男休學助家計 未料單親父罹癌「心慌」
# 19976   新聞     片子演得都真的！調查：6成台人性幻想對
# 19977   問卦           為啥白天會有特別多黑人的文
# 19978   問卦           跟肥宅十指緊扣是什麼感覺？
# 19979   新聞    北市8日起擴大機車格收費 自主開單省5元
# 19980   問卦               怎樣才能被女生跟蹤
# 19981   新聞    見黑絲忍不住！人夫跟上扶梯...「手快速
# 19982   問卦                高雄現在哪裡最陰
# 19983   問卦          有沒有教學大樓怎麼取名的八卦
# 19984   問卦           殷素素怎麼變成元朝的郡主？
# 19985   問卦             屯門爆發無差別襲擊耶！
# 19986   問卦         原以為是龍蛋 結果孵出來是隻貓
# 19987   問卦              中山區是便宜的區嗎？
# 19988   問卦       MacBook Pro變很慢怎辦？
# 19989   問卦             中職哪隊球迷最像韓粉？
# 19990   問卦       一樣是走私 有人罰五萬，有人被關？
# 19991   問卦           欸欸 憲哥下一步要怎麼走啊
# 19992   問卦  年薪95W身高未滿165不帥有機會交女友嗎？
# 19993   新聞     陽台古早「太陽花」欄杆 原來有這個作用
# 19994   問卦                    復活了？
# 19995   問卦            你各位會以碗就口嗎？？？
# 19996   問卦           握推手腕到底可不可以彎阿？
# 19997   問卦         佐佐木美玲的中文程度到底如何？
# 19998   問卦     欸欸欸 講話是不是一定要多XD比較好?
# 19999   問卦           Ptt棋院怎麼沒有黑白棋?
#
#                                                  content
# 0      \n號稱台灣版驚安の殿堂的小北百貨\n\n24小時全年無休五金百貨生活百貨應有盡有\n\n在...
# 1      \n※發文無1~6小標格式或未依順序任意刪除者會被刪文\n\n1.媒體來源:聯合報\n※ 例...
# 2      \n\n疑？阿不是只要有警察的新聞出現在八卦版\n八卦覺青就會高潮？\n每次不是都愛拿太陽花...
# 3      \n謝鑫佑被唬到大 小說寫覆鼎金多年後成預言\n\n（中央社記者鄭景雯台北3日電）「我跟馬奎...
# 4      \n※發文無1~6小標格式或未依順序任意刪除者會被刪文\n\n1.媒體來源:\n※ 例如蘋果...
# 5      \n在第一眼 我就明白\n肥宅有看到妹子ㄉ表情\n就知道又要去警察局ㄌ\n沒有女森要裡肥宅\...
# 6      \n\n1.媒體來源:TVBS\n2.記者吳允芊\n\n3.完整新聞標題:\n日本「最可愛女...
# 7      \n1.媒體來源:\n聯合報/聯合新聞網即時消息\n2.記者署名:記者林則宏\n3.完整新聞...
# 8      \n買了一堆餅乾雜糧避難\n\n好險颱風北漂沒事\n\n但今天銷貨的時候 心裡有些沮喪\n\...
# 9      \n左岸近平老兄一家人都外國人\n\n那不就表示他自己也知道自由民主的可貴\n\n既然這樣 ...
# 10     \n\n標題塞不下\n我比較想問的是\n真正害了香港的人\n是不是當初沒反對回歸中國的人\n...
# 11     \n\n如題\n\n之前有痛車的時候真的很用心><\n\n連天花板都有小穹在看著大家><\n...
# 12     \n1.媒體來源:\n中時\n\n\n2.記者署名\n丁世傑\n\n\n3.完整新聞標題:\...
# 13     \n--------------------- (0.1) 前言 -------------...
# 14     \n是這樣的，剛剛本宅走入霞飛路76號\n晃著晃著突然就有個穿軍服的日本人過來\n施了一招鴛...
# 15     \n如題\n\n一直睡不著怎麼辦？\n\n再尻一發？\n\n開始數棉羊？\n\n直接不睡到天...
# 16     \n那個，\n我一直不能理解，\n方芮欣明明也沒做錯什麼，\n為什麼要遭受審判耶？\n\n反...
# 17     \n乳題啦\n本肥朋友\n女孩兒\n心情不好\n問她要不要來本肥家住\n她縮好\n本肥因該注...
# 18     \n2018年\n台灣人平均收入\n60%的人在四萬五以內\n\n十萬塊\n是這個數字的兩倍...
# 19     \n距離150萬達成後好久才到160萬\n\n真是辛苦Joeman了 越被過氣肥宅兄弟粉黑就...
# 20     \n這些人多數是出生在臺灣\n或是小時候成長於臺灣\n之後到中國唸書 工作 生活\n被國民黨...
# 21     \n手機壞了。\n前幾天颱風天下大雨時被大雨淋壞了。\n人家都戲稱常山趙子龍七進七出，\n用...
# 22     \n如題\n\n我跟家人到加拿大探望親戚\n\n不過我跟親戚不熟 對唱K也不感興趣\n\n然...
# 23     \n綜觀近代史，不管獨裁的邪惡帝國再怎麼天怒人怨\n\n只要沒有對外戰爭，幾乎都可以穩穩的，...
# 24     \n一般人吸收水分 都是用喝的\n\n但是我聽說野外求生的專家 遭難時\n\n無法取得乾淨的...
# 25     \n\n對戰蔡英文、韓國瑜　林濁水：柯文哲得到年輕世代支持的神話已破滅\n\nEttoday...
# 26     \n名DJ慘死 粉絲葬禮發狂開棺驗屍\n\n10:16 2019/09/01 中時電子報 吳...
# 27     \n山田勝己找了一堆人來訓練取了一個黑虎軍團的稱號可是都在第一關全軍覆沒。\n可是長野誠只帶...
# 28     \n\n\n\n\n2015年8月7日\n\n強烈蘇迪勒颱風席捲台灣\n\n第二天早上也就是...
# 29     \n※ 八卦板務請到 GossipPicket 檢舉板詢問\n※ a.張貼問卦請注意，充實文...
# ...                                                  ...
# 19970  \n大家安安^^\n\n本肥宅小時候寫名子都被老師打錯啦\n\n都說要寫名字才對\n\n但是...
# 19971  \n不捨勇警殉職！李來希怒揭原因嗆爆小英\n\n10:26 2019/07/06\n\n中時...
# 19972  \n最近不知為何又拿當初砍七天假出來吵\n\n首先1.  那七天假原本就是一些阿里不答的假 ...
# 19973  \n客家料理有很多有名的菜餚\n\n其中有一道是叫客家小炒\n\n就是豆乾 魷魚乾 豬肉 炒...
# 19974  \n過了今天23:59\n明天發文門檻就要提高了\n到時候八卦板會發生什麼事?\n\n我覺得...
# 19975  \n有推有批幣 總共發出1000P\nhttps://tw.appledaily.com/h...
# 19976  \n1.媒體來源:\n三立新聞\n\n2.記者署名\n記者李鴻典／台北報導\n\n3.完整新...
# 19977  \n\n我想最近大家都注意到\n每次到了白天\n突然一堆黑某人的文章洗滿整頁\n\n但是到了...
# 19978  \n如果跟肥宅感情很好\n\n牽手不只單純牽手\n\n還十指緊扣\n\n那會是什麼感覺\n\...
# 19979  \nhttps://m.ltn.com.tw/news/Taipei/paper/13008...
# 19980  \nHihi,  e  cup  ,  30  cm,\n\n大家好，\n\n聽說企鵝妹被跟...
# 19981  \n八卦-1，肥宅悲歌\n\n\n見黑絲忍不住！人夫跟上扶梯...「手快速前後」猛噴2女　她...
# 19982  \n再過不久就是飄月了\n一直以來\n高雄盛名陰地不外乎是旗津 覆頂金 忠烈祠等\n聽說過港...
# 19983  \n\n小時候都會為教學大樓取名，像勤學樓、化育樓、和平樓，為什麼沒有紅樓呢？\n\n---...
# 19984  \n各位肥宅安安\n\n本魯剛剛看到一部電影\n\n本來殷素素是張翠山的老婆\n\n後來自殺...
# 19985  \n\n今天香港警察雇用來殺光光抗議民眾的白衣人又出來了，\n\n出來針對黑色衣服的屯門抗議...
# 19986  \n各位安安\n我有一個朋友跟我說\n他有天走在森林 對著一棵大樹用拳頭敲敲打打\n結果掉下...
# 19987  \n中山區靠近松山、大同區\n\n比較有名的就林森北路很多酒店\n\n還有南京西路商圈\n\...
# 19988  \n\n本魯的MacBook pro用了大概6年\n\n\n開始變好慢\n\n\n銀幕也脫膜...
# 19989  \n韓粉特色 重義氣 草根性 人多勢眾\n\n得罪的下場被出征\n\n請問中職四隊中哪隊的球...
# 19990  \nhttps://i.imgur.com/1Zm6EOG.jpg\n\n去年三月，一名漁民...
# 19991  \n\n舉球手憲哥\n今天被館長狠狠叩殺\n看憲哥臉書被圍剿\n情況岌岌可危\n聰明的憲哥\...
# 19992  \n幫同事問，\n\n小魯同事31歲多，\n\n身高不到 165 cm，\n\n人長得雖然不...
# 19993  \n陽台古早「太陽花」欄杆 原來有這個作用\n記者林國賢\nhttps://news.ltn...
# 19994  \n現在才六點半\n\n世界末日是不是提早結束了\n\n有沒有八卦\n\n一整天沒有PTT真...
# 19995  \n\n乳題，是這樣啦\n小弟現在出來吃飯，環顧四周\n以碗就口的包括我就只有兩個\n其他的...
# 19996  \n\n\n各位巨巨大家晚安大家好\n小弟是習慣不彎喇\n就是往上推時手腕跟手臂成一直線\n...
# 19997  \nhttps://imgur.com/Lm0FbuA.jpg\n\n佐佐木美玲小時候曾經住...
# 19998  \n乳體\n\n是這樣的拉XD\n\n本肥宅常常看到有人在網路上亂嗆人\n\n結果就被對方吉...
# 19999  \n黑白棋的介面在Ptt上面應該不難設計才對\n\n日本人超愛下黑白棋，風行程度更是超過日本...
#
# [20000 rows x 3 columns]

# %%
# 使用 jieba 進行分詞
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import jieba
import os
from urllib.request import urlretrieve

# 使用大型字典
big_dict_path = "dict.txt.big"
if not os.path.exists(big_dict_path):
    print("下載大型字典")
    url = "https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big"
    urlretrieve(url, big_dict_path)
jieba.set_dictionary(big_dict_path)

# 需加入一些鄉民常用字彙
ptt_dict_path = "ptt_dic.txt"
if os.path.exists(ptt_dict_path):
    print("載入ptt專用詞典")
    jieba.load_userdict(ptt_dict_path)
# Out:
# Building prefix dict from /Users/Elwing/Machine_Learning/NLP/dict.txt.big ...
# 載入ptt專用詞典
# Dumping model to file cache /var/folders/wv/6kw6f9sx5mqdrjl6820mgzfm0000gn/T/jieba.u91d159a65f80d44bcf55459b085e5237.cache
# Loading model cost 2.020 seconds.
# Prefix dict has been built succesfully.

# %%
punct = set(u''':!),.:;?]}¢'"、。〉》」』】〕〗〞︰︱︳﹐､﹒﹔﹕﹖﹗﹚﹜﹞！），．：；？｜｝︴︶︸︺︼︾﹀﹂﹄﹏､～￠々‖•·ˇˉ―--′’”([{£¥'"‵〈《「『【〔〖（［｛￡￥〝︵︷︹︻︽︿﹁﹃﹙﹛﹝（｛“‘-—_…~/ －＊➜■─★☆=@<>◉é''')

# %%
import re
# 對表格的每一筆都做出轉換
def process(content):
    content = re.sub(r'https?:\/\/.*[\r\n]*', '', content)
    fil = filter(lambda x: x not in punct, jieba.cut(content))
    content = " ".join(fil)
    return content

process(df["content"][0])
# Out:
# '\n 號稱 台灣版 驚安 の 殿堂 的 小北 百貨 \n \n 24 小時 全年 無休 五金 百貨 生活 百貨 應有盡有 \n \n 在 台灣 有 上 百家 分店 \n \n 小北 若 去 日本 展店 會 被 唐吉訶德 一拳 打死 嗎 \n \n \n'

# %%
content_cut = df["content"].apply(process)
content_cut
# Out:
# 0        \n 號稱 台灣版 驚安 の 殿堂 的 小北 百貨 \n \n 24 小時 全年 無休 五金...
# 1        \n ※ 發文 無 1 6 小 標格 式 或 未 依 順序 任意 刪除 者 會 被刪 文 \...
# 2        \n \n 疑 阿 不是 只要 有 警察 的 新聞 出現 在 八卦 版 \n 八卦 覺青 就...
# 3        \n 謝鑫佑 被 唬 到 大 小說 寫 覆鼎金 多年 後 成 預言 \n \n 中央社 記者...
# 4        \n ※ 發文 無 1 6 小 標格 式 或 未 依 順序 任意 刪除 者 會 被刪 文 \...
# 5        \n 在 第一眼 我 就 明白 \n 肥宅 有 看到 妹子 ㄉ 表情 \n 就 知道 又 要...
# 6        \n \n 1 媒體 來源 TVBS \n 2 記者 吳允 芊 \n \n 3 完整 新聞標...
# 7        \n 1 媒體 來源 \n 聯合報 聯合 新聞網 即時消息 \n 2 記者 署名 記者 林則...
# 8        \n 買 了 一堆 餅乾 雜糧 避難 \n \n 好險 颱風 北漂 沒事 \n \n 但 今...
# 9        \n 左岸 近平 老兄 一家人 都 外國人 \n \n 那不就 表示 他 自己 也 知道 自...
# 10       \n \n 標題 塞 不下 \n 我 比較 想問 的 是 \n 真正 害 了 香港 的 人 ...
# 11       \n \n 如 題 \n \n 之前 有 痛車 的 時候 真的 很 用心 \n \n 連 天...
# 12       \n 1 媒體 來源 \n 中時 \n \n \n 2 記者 署名 \n 丁世傑 \n \n...
# 13       \n 0.1 前言 \n \n \n 小弟 Ⓟ 快 發完 了 所以 先 賺 稿費 第 7 期...
# 14       \n 是 這樣 的 剛剛 本宅 走入 霞飛路 76 號 \n 晃 著晃著 突然 就 有 個 ...
# 15       \n 如 題 \n \n 一直 睡不著 怎麼辦 \n \n 再 尻 一發 \n \n 開始 ...
# 16       \n 那個 \n 我 一直 不能 理解 \n 方芮欣 明明 也 沒 做 錯 什麼 \n 為 ...
# 17       \n 乳題 啦 \n 本肥 朋友 \n 女孩兒 \n 心情 不好 \n 問 她 要 不 要來...
# 18       \n 2018 年 \n 台灣 人 平均收入 \n 60 % 的 人 在 四萬 五 以內 \...
# 19       \n 距離 150 萬 達成 後 好久 才 到 160 萬 \n \n 真是 辛苦 Joem...
# 20       \n 這些 人 多數 是 出生 在 臺灣 \n 或是 小時候 成 長於 臺灣 \n 之後 到...
# 21       \n 手機 壞 了 \n 前 幾天 颱風 天下 大雨 時 被 大雨淋 壞 了 \n 人家 都...
# 22       \n 如 題 \n \n 我 跟 家人 到 加拿大 探望 親戚 \n \n 不過 我 跟 親...
# 23       \n 綜觀 近代史 不管 獨裁 的 邪惡 帝國 再 怎麼 天怒人怨 \n \n 只要 沒有 ...
# 24       \n 一般 人 吸收 水分 都 是 用 喝 的 \n \n 但是 我 聽說 野外求生 的 專...
# 25       \n \n 對戰 蔡 英文 韓國 瑜 　 林 濁水 柯文 哲 得到 年輕 世代 支持 的 神...
# 26       \n 名 DJ 慘死 粉絲 葬禮 發狂 開棺驗屍 \n \n 10 16 2019 09 0...
# 27       \n 山田 勝己 找 了 一堆 人來 訓練 取 了 一個 黑虎 軍團 的 稱號 可是 都 在...
# 28       \n \n \n \n \n 2015 年 8 月 7 日 \n \n 強烈 蘇迪勒 颱風 ...
# 29       \n ※ 八卦 板 務請 到 GossipPicket 檢舉 板 詢問 \n ※ a 張貼 ...
#                                ...
# 19970    \n 大家 安安 ^ ^ \n \n 本 肥宅 小時候 寫 名子 都 被 老師 打錯 啦 \...
# 19971    \n 不 捨 勇警 殉職 李來 希怒 揭 原因 嗆 爆小英 \n \n 10 26 2019...
# 19972    \n 最近 不知 為何 又 拿 當初 砍 七天 假 出來 吵 \n \n 首先 1 那 七天...
# 19973    \n 客家 料理 有 很多 有名 的 菜餚 \n \n 其中 有 一道 是 叫 客家 小炒 ...
# 19974    \n 過了 今天 23 59 \n 明天 發文 門檻 就要 提高 了 \n 到時候 八卦 板...
# 19975    \n 有 推有 批幣 總共 發出 1000P \n 貧男 休學 助 家計 未 料單 親父 罹...
# 19976    \n 1 媒體 來源 \n 三立 新聞 \n \n 2 記者 署名 \n 記者 李鴻典 ／ ...
# 19977    \n \n 我 想 最近 大家 都 注意 到 \n 每次 到 了 白天 \n 突然 一堆 黑...
# 19978    \n 如果 跟 肥宅 感情 很 好 \n \n 牽手 不 只 單純 牽手 \n \n 還 十...
# 19979    \n 北市 8 日起 擴大 機車 格 收費 自主 開單 省 5 元 \n 自由 時報 201...
# 19980    \n Hihi e cup 30 cm \n \n 大家 好 \n \n 聽說 企鵝 妹 被...
# 19981    \n 八卦 1 肥宅 悲歌 \n \n \n 見 黑絲 忍不住 人夫 跟上 扶梯 ... 手...
# 19982    \n 再 過 不久 就是 飄 月 了 \n 一直 以來 \n 高雄 盛名 陰 地 不外乎 是...
# 19983    \n \n 小時候 都 會 為 教學大樓 取名 像 勤學 樓 化育 樓 和平 樓 為 什麼 ...
# 19984    \n 各位 肥宅 安安 \n \n 本魯 剛剛 看到 一部 電影 \n \n 本來 殷素素 ...
# 19985    \n \n 今天 香港 警察 雇 用來 殺光 光 抗議 民眾 的 白衣 人 又 出來 了 \...
# 19986    \n 各位 安安 \n 我 有 一個 朋友 跟 我 說 \n 他 有 天 走 在 森林 對著...
# 19987    \n 中 山區 靠近 松山 大同區 \n \n 比較 有名 的 就 林森北路 很多 酒店 \...
# 19988    \n \n 本魯 的 MacBook pro 用 了 大概 6 年 \n \n \n 開始 ...
# 19989    \n 韓粉 特色 重義氣 草根 性 人多 勢眾 \n \n 得罪 的 下場 被 出征 \n ...
# 19990    \n 去年 三月 一名 漁民 走私 20 條 香菸 \n \n 被 罰 了 三萬多 而且 被...
# 19991    \n \n 舉 球手 憲哥 \n 今天 被 館長 狠狠 叩殺 \n 看憲哥 臉書 被 圍剿 ...
# 19992    \n 幫 同事 問 \n \n 小魯 同事 31 歲 多 \n \n 身高 不到 165 c...
# 19993    \n 陽台 古早 太陽 花 欄杆 原來 有 這個 作用 \n 記者 林國賢 \n 記者 林國...
# 19994    \n 現在 才 六點半 \n \n 世界末日 是不是 提早 結束 了 \n \n 有沒有 八...
# 19995    \n \n 乳題 是 這樣 啦 \n 小弟 現在 出來 吃飯 環顧四周 \n 以碗 就 口 ...
# 19996    \n \n \n 各位 巨 巨大 家 晚安 大家 好 \n 小弟 是 習慣 不彎 喇 \n ...
# 19997    \n 佐佐木 美玲 小時候 曾經 住過 台灣 \n \n 也 曾 在 節目 中 透露 這段 ...
# 19998    \n 乳體 \n \n 是 這樣 的 拉 XD \n \n 本 肥宅 常常 看到 有人 在 ...
# 19999    \n 黑白棋 的 介面 在 Ptt 上面 應該 不難 設計 才 對 \n \n 日本 人 超...
# Name: content, Length: 20000, dtype: object

# %%
df["cut"] = content_cut
df.to_csv("pttsmall.csv", encoding="utf-8", index=False)

# %%
f = open("pttsmalljoin.txt", "w", encoding="utf-8")
for content in content_cut:
    f.write("{}\n".format(content))
f.close()

# %%
# %%time
from gensim.models import word2vec
sentences = word2vec.LineSentence('pttsmalljoin.txt')
model = word2vec.Word2Vec(sentences)
# Out:
# CPU times: user 45.5 s, sys: 536 ms, total: 46 s
# Wall time: 25.3 s

# %%
model.wv["版主"]
# Out:
# array([-0.5031468 ,  0.85385495,  0.01468529,  0.38329545,  0.9236413 ,
#         1.3322514 , -0.5726766 ,  1.893805  , -0.06489053, -0.34709686,
#         1.0491568 , -0.746913  , -0.2630203 ,  0.60751706,  0.6895506 ,
#        -0.3646925 ,  0.31532225, -0.5254028 ,  0.20952474,  0.20227425,
#         0.26262626, -0.21642016,  0.04825654, -1.0350652 , -1.439426  ,
#        -0.76219475,  0.52309704,  0.9436407 , -1.0148262 ,  0.2333282 ,
#         0.12925285,  0.08473273, -0.1694073 , -0.2741679 , -0.34143388,
#        -0.6145993 , -0.31068715,  0.6392033 ,  0.13618837,  0.7914982 ,
#        -0.35989237,  0.12207969, -1.3062565 , -0.10228308, -0.17957455,
#         0.24936599,  0.6566916 , -0.42996064, -0.1323898 , -0.46875283,
#        -0.59352654, -1.182087  ,  0.86105144,  0.09028633, -1.6626117 ,
#        -0.33722845, -0.75998807,  0.9831453 ,  0.23200934, -0.72885215,
#        -1.0433626 , -0.4358668 ,  0.17441653,  0.17349969, -0.72495294,
#        -0.07144459, -0.7097036 ,  0.18731076,  1.1772293 ,  0.98349005,
#        -0.27714565,  1.757287  , -0.48160547,  0.4459305 ,  0.6818631 ,
#         0.95228344,  0.09833045,  0.12402005,  0.5406698 , -0.36434817,
#         0.15948924, -1.1087006 ,  0.5351972 ,  0.5221398 ,  0.06871287,
#         0.18933551,  1.1415538 ,  0.11230113, -0.39598808, -0.766633  ,
#         0.716373  ,  1.1009654 ,  0.6882628 , -0.9116525 ,  0.12060928,
#        -0.03586073, -0.08405054,  0.82503915, -0.23686157,  0.33566234],
#       dtype=float32)

# %%
model.wv.most_similar("版主")
# Out:
# [('署名', 0.7429673075675964),
#  ('水桶', 0.6693310737609863),
#  ('刪除', 0.6688295006752014),
#  ('該報', 0.6453143358230591),
#  ('版面', 0.6358105540275574),
#  ('NOWnews', 0.6325187087059021),
#  ('華視', 0.6227239370346069),
#  ('編輯部', 0.6150052547454834),
#  ('打假', 0.6148825883865356),
#  ('Yahoo', 0.6135222315788269)]

# %%
len(model.wv.vocab)
# Out:
# 41519

# %%
model.wv.vocab
# Out:
# {'號稱': <gensim.models.keyedvectors.Vocab at 0x13bdf6cc0>,
#  '台灣版': <gensim.models.keyedvectors.Vocab at 0x13bdf66a0>,
#  '驚安': <gensim.models.keyedvectors.Vocab at 0x13bdf6f60>,
#  'の': <gensim.models.keyedvectors.Vocab at 0x13bdf6c50>,
#  '殿堂': <gensim.models.keyedvectors.Vocab at 0x13bdf6748>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x13bdf6d30>,
#  '小北': <gensim.models.keyedvectors.Vocab at 0x13bdf6d68>,
#  '百貨': <gensim.models.keyedvectors.Vocab at 0x13bdf6860>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x13bdf6f28>,
#  '小時': <gensim.models.keyedvectors.Vocab at 0x13bdf6ef0>,
#  '全年': <gensim.models.keyedvectors.Vocab at 0x13bdf6a58>,
#  '無休': <gensim.models.keyedvectors.Vocab at 0x13bdf6da0>,
#  '五金': <gensim.models.keyedvectors.Vocab at 0x13bdf6dd8>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x13bdf6e10>,
#  '應有盡有': <gensim.models.keyedvectors.Vocab at 0x13bdf6e48>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x13bdf6e80>,
#  '台灣': <gensim.models.keyedvectors.Vocab at 0x13bdf6eb8>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x13bdf6f98>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x13bdf6fd0>,
#  '分店': <gensim.models.keyedvectors.Vocab at 0x13be01048>,
#  '若': <gensim.models.keyedvectors.Vocab at 0x13be01080>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x13be010b8>,
#  '日本': <gensim.models.keyedvectors.Vocab at 0x13be010f0>,
#  '展店': <gensim.models.keyedvectors.Vocab at 0x13be01128>,
#  '會': <gensim.models.keyedvectors.Vocab at 0x13be01160>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x13be01198>,
#  '唐吉訶德': <gensim.models.keyedvectors.Vocab at 0x13be011d0>,
#  '一拳': <gensim.models.keyedvectors.Vocab at 0x13be01208>,
#  '打死': <gensim.models.keyedvectors.Vocab at 0x13be01240>,
#  '嗎': <gensim.models.keyedvectors.Vocab at 0x13be01278>,
#  '※': <gensim.models.keyedvectors.Vocab at 0x13be012b0>,
#  '發文': <gensim.models.keyedvectors.Vocab at 0x13be012e8>,
#  '無': <gensim.models.keyedvectors.Vocab at 0x13be01320>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x13be01358>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x13be01390>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x13be013c8>,
#  '標格': <gensim.models.keyedvectors.Vocab at 0x13be01400>,
#  '式': <gensim.models.keyedvectors.Vocab at 0x13be01438>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x13be01470>,
#  '未': <gensim.models.keyedvectors.Vocab at 0x13be014a8>,
#  '依': <gensim.models.keyedvectors.Vocab at 0x13be014e0>,
#  '順序': <gensim.models.keyedvectors.Vocab at 0x13be01518>,
#  '任意': <gensim.models.keyedvectors.Vocab at 0x13be01550>,
#  '刪除': <gensim.models.keyedvectors.Vocab at 0x13be01588>,
#  '者': <gensim.models.keyedvectors.Vocab at 0x13be015c0>,
#  '被刪': <gensim.models.keyedvectors.Vocab at 0x13be015f8>,
#  '文': <gensim.models.keyedvectors.Vocab at 0x13be01630>,
#  '媒體': <gensim.models.keyedvectors.Vocab at 0x13be01668>,
#  '來源': <gensim.models.keyedvectors.Vocab at 0x13be016a0>,
#  '聯合報': <gensim.models.keyedvectors.Vocab at 0x13be016d8>,
#  '例如': <gensim.models.keyedvectors.Vocab at 0x13be01710>,
#  '蘋果日報': <gensim.models.keyedvectors.Vocab at 0x13be01748>,
#  '自由': <gensim.models.keyedvectors.Vocab at 0x13be01780>,
#  '時報': <gensim.models.keyedvectors.Vocab at 0x13be017b8>,
#  '請': <gensim.models.keyedvectors.Vocab at 0x13be017f0>,
#  '參考': <gensim.models.keyedvectors.Vocab at 0x13be01828>,
#  '版規': <gensim.models.keyedvectors.Vocab at 0x13be01860>,
#  '下方': <gensim.models.keyedvectors.Vocab at 0x13be01898>,
#  '核准': <gensim.models.keyedvectors.Vocab at 0x13be018d0>,
#  '名單': <gensim.models.keyedvectors.Vocab at 0x13be01908>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x13be01940>,
#  '記者': <gensim.models.keyedvectors.Vocab at 0x13be01978>,
#  '署名': <gensim.models.keyedvectors.Vocab at 0x13be019b0>,
#  '周': <gensim.models.keyedvectors.Vocab at 0x13be019e8>,
#  '志豪': <gensim.models.keyedvectors.Vocab at 0x13be01a20>,
#  '沒有': <gensim.models.keyedvectors.Vocab at 0x13be01a58>,
#  '這打': <gensim.models.keyedvectors.Vocab at 0x13be01a90>,
#  '新聞': <gensim.models.keyedvectors.Vocab at 0x13be01ac8>,
#  '水桶': <gensim.models.keyedvectors.Vocab at 0x13be01b00>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x13be01b38>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x13be01b70>,
#  '編輯': <gensim.models.keyedvectors.Vocab at 0x13be01ba8>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x13be01be0>,
#  '外電': <gensim.models.keyedvectors.Vocab at 0x13be01c18>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x13be01c50>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x13be01c88>,
#  '如': <gensim.models.keyedvectors.Vocab at 0x13be01cc0>,
#  '法新社': <gensim.models.keyedvectors.Vocab at 0x13be01cf8>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x13be01d30>,
#  '完整': <gensim.models.keyedvectors.Vocab at 0x13be01d68>,
#  '新聞標題': <gensim.models.keyedvectors.Vocab at 0x13be01da0>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x13be01dd8>,
#  '排入': <gensim.models.keyedvectors.Vocab at 0x13be01e10>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x13be01e48>,
#  '分區': <gensim.models.keyedvectors.Vocab at 0x13be01e80>,
#  '立委': <gensim.models.keyedvectors.Vocab at 0x13be01eb8>,
#  '李': <gensim.models.keyedvectors.Vocab at 0x13be01ef0>,
#  '昭平': <gensim.models.keyedvectors.Vocab at 0x13be01f28>,
#  '吳敦義': <gensim.models.keyedvectors.Vocab at 0x13be01f60>,
#  '從沒': <gensim.models.keyedvectors.Vocab at 0x13be01f98>,
#  '考慮': <gensim.models.keyedvectors.Vocab at 0x13be01fd0>,
#  '放': <gensim.models.keyedvectors.Vocab at 0x13be03048>,
#  '第一名': <gensim.models.keyedvectors.Vocab at 0x13be03080>,
#  '標題': <gensim.models.keyedvectors.Vocab at 0x13be030b8>,
#  '寫': <gensim.models.keyedvectors.Vocab at 0x13be030f0>,
#  '出來': <gensim.models.keyedvectors.Vocab at 0x13be03128>,
#  '依照': <gensim.models.keyedvectors.Vocab at 0x13be03160>,
#  '板規': <gensim.models.keyedvectors.Vocab at 0x13be03198>,
#  '文章': <gensim.models.keyedvectors.Vocab at 0x13be031d0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x13be03208>,
#  '內文': <gensim.models.keyedvectors.Vocab at 0x13be03240>,
#  '國民黨': <gensim.models.keyedvectors.Vocab at 0x13be03278>,
#  '主席': <gensim.models.keyedvectors.Vocab at 0x13be032b0>,
#  '是否': <gensim.models.keyedvectors.Vocab at 0x13be032e8>,
#  '下屆': <gensim.models.keyedvectors.Vocab at 0x13be03320>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x13be03358>,
#  '究竟': <gensim.models.keyedvectors.Vocab at 0x13be03390>,
#  '要排': <gensim.models.keyedvectors.Vocab at 0x13be033c8>,
#  '邊緣': <gensim.models.keyedvectors.Vocab at 0x13be03400>,
#  '各種': <gensim.models.keyedvectors.Vocab at 0x13be03438>,
#  '聲音': <gensim.models.keyedvectors.Vocab at 0x13be03470>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x13be034a8>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x13be034e0>,
#  '常委': <gensim.models.keyedvectors.Vocab at 0x13be03518>,
#  '受訪': <gensim.models.keyedvectors.Vocab at 0x13be03550>,
#  '時': <gensim.models.keyedvectors.Vocab at 0x13be03588>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x13be035c0>,
#  '吳': <gensim.models.keyedvectors.Vocab at 0x13be035f8>,
#  '上午': <gensim.models.keyedvectors.Vocab at 0x13be03630>,
#  '出席': <gensim.models.keyedvectors.Vocab at 0x13be03668>,
#  '全國': <gensim.models.keyedvectors.Vocab at 0x13be036a0>,
#  '勞工': <gensim.models.keyedvectors.Vocab at 0x13be036d8>,
#  '後援會': <gensim.models.keyedvectors.Vocab at 0x13be03710>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x13be03748>,
#  '問': <gensim.models.keyedvectors.Vocab at 0x13be03780>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x13be037b8>,
#  '相關': <gensim.models.keyedvectors.Vocab at 0x13be037f0>,
#  '問題': <gensim.models.keyedvectors.Vocab at 0x13be03828>,
#  '從來': <gensim.models.keyedvectors.Vocab at 0x13be03860>,
#  '放在': <gensim.models.keyedvectors.Vocab at 0x13be03898>,
#  '說': <gensim.models.keyedvectors.Vocab at 0x13be038d0>,
#  '早上': <gensim.models.keyedvectors.Vocab at 0x13be03908>,
#  '開': <gensim.models.keyedvectors.Vocab at 0x13be03940>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x13be03978>,
#  '詢問': <gensim.models.keyedvectors.Vocab at 0x13be039b0>,
#  '是不是': <gensim.models.keyedvectors.Vocab at 0x13be039e8>,
#  '第一': <gensim.models.keyedvectors.Vocab at 0x13be03a20>,
#  '名': <gensim.models.keyedvectors.Vocab at 0x13be03a58>,
#  '回答': <gensim.models.keyedvectors.Vocab at 0x13be03a90>,
#  '絕對': <gensim.models.keyedvectors.Vocab at 0x13be03ac8>,
#  '過': <gensim.models.keyedvectors.Vocab at 0x13be03b00>,
#  '這件': <gensim.models.keyedvectors.Vocab at 0x13be03b38>,
#  '事情': <gensim.models.keyedvectors.Vocab at 0x13be03b70>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x13be03ba8>,
#  '這個': <gensim.models.keyedvectors.Vocab at 0x13be03be0>,
#  '考量': <gensim.models.keyedvectors.Vocab at 0x13be03c18>,
#  '認為': <gensim.models.keyedvectors.Vocab at 0x13be03c50>,
#  '事實上': <gensim.models.keyedvectors.Vocab at 0x13be03c88>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x13be03cc0>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x13be03cf8>,
#  '這樣': <gensim.models.keyedvectors.Vocab at 0x13be03d30>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x13be03d68>,
#  '毫無意義': <gensim.models.keyedvectors.Vocab at 0x13be03da0>,
#  '黨內': <gensim.models.keyedvectors.Vocab at 0x13be03dd8>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x13be03e10>,
#  '能夠': <gensim.models.keyedvectors.Vocab at 0x13be03e48>,
#  '後': <gensim.models.keyedvectors.Vocab at 0x13be03e80>,
#  '段': <gensim.models.keyedvectors.Vocab at 0x13be03eb8>,
#  '安全': <gensim.models.keyedvectors.Vocab at 0x13be03ef0>,
#  '後面': <gensim.models.keyedvectors.Vocab at 0x13be03f28>,
#  '一點': <gensim.models.keyedvectors.Vocab at 0x13be03f60>,
#  '的話': <gensim.models.keyedvectors.Vocab at 0x13be03f98>,
#  '對': <gensim.models.keyedvectors.Vocab at 0x13be03fd0>,
#  '大家': <gensim.models.keyedvectors.Vocab at 0x13be07048>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x13be07080>,
#  '領頭羊': <gensim.models.keyedvectors.Vocab at 0x13be070b8>,
#  '往前': <gensim.models.keyedvectors.Vocab at 0x13be070f0>,
#  '衝': <gensim.models.keyedvectors.Vocab at 0x13be07128>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x13be07160>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x13be07198>,
#  '意義': <gensim.models.keyedvectors.Vocab at 0x13be071d0>,
#  '根本': <gensim.models.keyedvectors.Vocab at 0x13be07208>,
#  '沒': <gensim.models.keyedvectors.Vocab at 0x13be07240>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x13be07278>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x13be072b0>,
#  '回應': <gensim.models.keyedvectors.Vocab at 0x13be072e8>,
#  '已經': <gensim.models.keyedvectors.Vocab at 0x13be07320>,
#  '決定': <gensim.models.keyedvectors.Vocab at 0x13be07358>,
#  '放入': <gensim.models.keyedvectors.Vocab at 0x13be07390>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x13be073c8>,
#  '有別': <gensim.models.keyedvectors.Vocab at 0x13be07400>,
#  '有沒有': <gensim.models.keyedvectors.Vocab at 0x13be07438>,
#  '知道': <gensim.models.keyedvectors.Vocab at 0x13be07470>,
#  '這是': <gensim.models.keyedvectors.Vocab at 0x13be074a8>,
#  '權力': <gensim.models.keyedvectors.Vocab at 0x13be074e0>,
#  '社論': <gensim.models.keyedvectors.Vocab at 0x13be07518>,
#  '特稿': <gensim.models.keyedvectors.Vocab at 0x13be07550>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x13be07588>,
#  '貼': <gensim.models.keyedvectors.Vocab at 0x13be075c0>,
#  '違者': <gensim.models.keyedvectors.Vocab at 0x13be075f8>,
#  '政治': <gensim.models.keyedvectors.Vocab at 0x13be07630>,
#  '類': <gensim.models.keyedvectors.Vocab at 0x13be07668>,
#  '個': <gensim.models.keyedvectors.Vocab at 0x13be076a0>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x13be076d8>,
#  '廣告': <gensim.models.keyedvectors.Vocab at 0x13be07710>,
#  '喔': <gensim.models.keyedvectors.Vocab at 0x13be07748>,
#  '可詳': <gensim.models.keyedvectors.Vocab at 0x13be07780>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x13be077b8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x13be077f0>,
#  '連結': <gensim.models.keyedvectors.Vocab at 0x13be07828>,
#  '短': <gensim.models.keyedvectors.Vocab at 0x13be07860>,
#  '網址': <gensim.models.keyedvectors.Vocab at 0x13be07898>,
#  '當': <gensim.models.keyedvectors.Vocab at 0x13be078d0>,
#  '過長': <gensim.models.keyedvectors.Vocab at 0x13be07908>,
#  '需': <gensim.models.keyedvectors.Vocab at 0x13be07940>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x13be07978>,
#  '方便': <gensim.models.keyedvectors.Vocab at 0x13be079b0>,
#  '網友': <gensim.models.keyedvectors.Vocab at 0x13be079e8>,
#  '點擊': <gensim.models.keyedvectors.Vocab at 0x13be07a20>,
#  '備註': <gensim.models.keyedvectors.Vocab at 0x13be07a58>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x13be07a90>,
#  '第二名': <gensim.models.keyedvectors.Vocab at 0x13be07ac8>,
#  '一個': <gensim.models.keyedvectors.Vocab at 0x13be07b00>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x13be07b38>,
#  '一天': <gensim.models.keyedvectors.Vocab at 0x13be07b70>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x13be07ba8>,
#  '張貼': <gensim.models.keyedvectors.Vocab at 0x13be07be0>,
#  '一則': <gensim.models.keyedvectors.Vocab at 0x13be07c18>,
#  '刪': <gensim.models.keyedvectors.Vocab at 0x13be07c50>,
#  '算': <gensim.models.keyedvectors.Vocab at 0x13be07c88>,
#  '額度': <gensim.models.keyedvectors.Vocab at 0x13be07cc0>,
#  '內': <gensim.models.keyedvectors.Vocab at 0x13be07cf8>,
#  '超貼': <gensim.models.keyedvectors.Vocab at 0x13be07d30>,
#  '注意': <gensim.models.keyedvectors.Vocab at 0x13be07d68>,
#  '疑': <gensim.models.keyedvectors.Vocab at 0x13be07da0>,
#  '阿': <gensim.models.keyedvectors.Vocab at 0x13be07dd8>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x13be07e10>,
#  '只要': <gensim.models.keyedvectors.Vocab at 0x13be07e48>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x13be07e80>,
#  '出現': <gensim.models.keyedvectors.Vocab at 0x13be07eb8>,
#  '八卦': <gensim.models.keyedvectors.Vocab at 0x13be07ef0>,
#  '版': <gensim.models.keyedvectors.Vocab at 0x13be07f28>,
#  '覺青': <gensim.models.keyedvectors.Vocab at 0x13be07f60>,
#  '高潮': <gensim.models.keyedvectors.Vocab at 0x13be07f98>,
#  '每次': <gensim.models.keyedvectors.Vocab at 0x13be07fd0>,
#  '太陽': <gensim.models.keyedvectors.Vocab at 0x13be0a048>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x13be0a080>,
#  '圖片': <gensim.models.keyedvectors.Vocab at 0x13be0a0b8>,
#  '火力': <gensim.models.keyedvectors.Vocab at 0x13be0a0f0>,
#  '支援': <gensim.models.keyedvectors.Vocab at 0x13be0a128>,
#  '怎麼': <gensim.models.keyedvectors.Vocab at 0x13be0a160>,
#  '從': <gensim.models.keyedvectors.Vocab at 0x13be0a198>,
#  '昨天': <gensim.models.keyedvectors.Vocab at 0x13be0a1d0>,
#  '發生': <gensim.models.keyedvectors.Vocab at 0x13be0a208>,
#  '現在': <gensim.models.keyedvectors.Vocab at 0x13be0a240>,
#  '每篇': <gensim.models.keyedvectors.Vocab at 0x13be0a278>,
#  '找': <gensim.models.keyedvectors.Vocab at 0x13be0a2b0>,
#  '不到': <gensim.models.keyedvectors.Vocab at 0x13be0a2e8>,
#  '貼圖': <gensim.models.keyedvectors.Vocab at 0x13be0a320>,
#  '惹': <gensim.models.keyedvectors.Vocab at 0x13be0a358>,
#  '風向': <gensim.models.keyedvectors.Vocab at 0x13be0a390>,
#  '風頭': <gensim.models.keyedvectors.Vocab at 0x13be0a3c8>,
#  '不敢': <gensim.models.keyedvectors.Vocab at 0x13be0a400>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x13be0a438>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x13be0a470>,
#  '助攻': <gensim.models.keyedvectors.Vocab at 0x13be0a4a8>,
#  '捅': <gensim.models.keyedvectors.Vocab at 0x13be0a4e0>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x13be0a518>,
#  '開心': <gensim.models.keyedvectors.Vocab at 0x13be0a550>,
#  '當初': <gensim.models.keyedvectors.Vocab at 0x13be0a588>,
#  '立法院': <gensim.models.keyedvectors.Vocab at 0x13be0a5c0>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x13be0a5f8>,
#  '打卡': <gensim.models.keyedvectors.Vocab at 0x13be0a630>,
#  '拍照': <gensim.models.keyedvectors.Vocab at 0x13be0a668>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x13be0a6a0>,
#  '呀': <gensim.models.keyedvectors.Vocab at 0x13be0a6d8>,
#  'Sent': <gensim.models.keyedvectors.Vocab at 0x13be0a710>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x13be0a748>,
#  'J': <gensim.models.keyedvectors.Vocab at 0x13be0a780>,
#  'PTT': <gensim.models.keyedvectors.Vocab at 0x13be0a7b8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x13be0a7f0>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x13be0a828>,
#  'Xiaomi': <gensim.models.keyedvectors.Vocab at 0x13be0a860>,
#  'MI': <gensim.models.keyedvectors.Vocab at 0x13be0a898>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x13be0a8d0>,
#  '謝鑫佑': <gensim.models.keyedvectors.Vocab at 0x13be0a908>,
#  '唬': <gensim.models.keyedvectors.Vocab at 0x13be0a940>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x13be0a978>,
#  '小說': <gensim.models.keyedvectors.Vocab at 0x13be0a9b0>,
#  '覆鼎金': <gensim.models.keyedvectors.Vocab at 0x13be0a9e8>,
#  '多年': <gensim.models.keyedvectors.Vocab at 0x13be0aa20>,
#  '成': <gensim.models.keyedvectors.Vocab at 0x13be0aa58>,
#  '預言': <gensim.models.keyedvectors.Vocab at 0x13be0aa90>,
#  '中央社': <gensim.models.keyedvectors.Vocab at 0x13be0aac8>,
#  '台北': <gensim.models.keyedvectors.Vocab at 0x13be0ab00>,
#  '日電': <gensim.models.keyedvectors.Vocab at 0x13be0ab38>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x13be0ab70>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x13be0aba8>,
#  '一樣': <gensim.models.keyedvectors.Vocab at 0x13be0abe0>,
#  '從小': <gensim.models.keyedvectors.Vocab at 0x13be0ac18>,
#  '被騙': <gensim.models.keyedvectors.Vocab at 0x13be0ac50>,
#  '小說家': <gensim.models.keyedvectors.Vocab at 0x13be0ac88>,
#  '個頭': <gensim.models.keyedvectors.Vocab at 0x13be0acc0>,
#  '憶起': <gensim.models.keyedvectors.Vocab at 0x13be0acf8>,
#  '童年': <gensim.models.keyedvectors.Vocab at 0x13be0ad30>,
#  '像': <gensim.models.keyedvectors.Vocab at 0x13be0ad68>,
#  '孩子': <gensim.models.keyedvectors.Vocab at 0x13be0ada0>,
#  '過往': <gensim.models.keyedvectors.Vocab at 0x13be0add8>,
#  '奇幻': <gensim.models.keyedvectors.Vocab at 0x13be0ae10>,
#  '五': <gensim.models.keyedvectors.Vocab at 0x13be0ae48>,
#  '囝': <gensim.models.keyedvectors.Vocab at 0x13be0ae80>,
#  '仙': <gensim.models.keyedvectors.Vocab at 0x13be0aeb8>,
#  '偷走': <gensim.models.keyedvectors.Vocab at 0x13be0aef0>,
#  '祕密': <gensim.models.keyedvectors.Vocab at 0x13be0af28>,
#  '虛構': <gensim.models.keyedvectors.Vocab at 0x13be0af60>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x13be0af98>,
#  '卻': <gensim.models.keyedvectors.Vocab at 0x13be0afd0>,
#  '事實': <gensim.models.keyedvectors.Vocab at 0x13be0d048>,
#  '如同': <gensim.models.keyedvectors.Vocab at 0x13be0d080>,
#  '2010': <gensim.models.keyedvectors.Vocab at 0x13be0d0b8>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x13be0d0f0>,
#  '高雄': <gensim.models.keyedvectors.Vocab at 0x13be0d128>,
#  '宣布': <gensim.models.keyedvectors.Vocab at 0x13be0d160>,
#  '縣市': <gensim.models.keyedvectors.Vocab at 0x13be0d198>,
#  '合併': <gensim.models.keyedvectors.Vocab at 0x13be0d1d0>,
#  '墓區': <gensim.models.keyedvectors.Vocab at 0x13be0d208>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x13be0d240>,
#  '地帶': <gensim.models.keyedvectors.Vocab at 0x13be0d278>,
#  '變成': <gensim.models.keyedvectors.Vocab at 0x13be0d2b0>,
#  '核心': <gensim.models.keyedvectors.Vocab at 0x13be0d2e8>,
#  '地區': <gensim.models.keyedvectors.Vocab at 0x13be0d320>,
#  '因': <gensim.models.keyedvectors.Vocab at 0x13be0d358>,
#  '公墓': <gensim.models.keyedvectors.Vocab at 0x13be0d390>,
#  '阻礙': <gensim.models.keyedvectors.Vocab at 0x13be0d3c8>,
#  '都市': <gensim.models.keyedvectors.Vocab at 0x13be0d400>,
#  '發展': <gensim.models.keyedvectors.Vocab at 0x13be0d438>,
#  '高雄市': <gensim.models.keyedvectors.Vocab at 0x13be0d470>,
#  '政府': <gensim.models.keyedvectors.Vocab at 0x13be0d4a8>,
#  '變更': <gensim.models.keyedvectors.Vocab at 0x13be0d4e0>,
#  '用地': <gensim.models.keyedvectors.Vocab at 0x13be0d518>,
#  '然而': <gensim.models.keyedvectors.Vocab at 0x13be0d550>,
#  '公頃': <gensim.models.keyedvectors.Vocab at 0x13be0d588>,
#  '約': <gensim.models.keyedvectors.Vocab at 0x13be0d5c0>,
#  '萬': <gensim.models.keyedvectors.Vocab at 0x13be0d5f8>,
#  '6000': <gensim.models.keyedvectors.Vocab at 0x13be0d630>,
#  '戶': <gensim.models.keyedvectors.Vocab at 0x13be0d668>,
#  '地上': <gensim.models.keyedvectors.Vocab at 0x13be0d6a0>,
#  '與': <gensim.models.keyedvectors.Vocab at 0x13be0d6d8>,
#  '超過': <gensim.models.keyedvectors.Vocab at 0x13be0d710>,
#  '萬個': <gensim.models.keyedvectors.Vocab at 0x13be0d748>,
#  '地下': <gensim.models.keyedvectors.Vocab at 0x13be0d780>,
#  '墓': <gensim.models.keyedvectors.Vocab at 0x13be0d7b8>,
#  '共計': <gensim.models.keyedvectors.Vocab at 0x13be0d7f0>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x13be0d828>,
#  '萬戶': <gensim.models.keyedvectors.Vocab at 0x13be0d860>,
#  '塚': <gensim.models.keyedvectors.Vocab at 0x13be0d898>,
#  '布滿': <gensim.models.keyedvectors.Vocab at 0x13be0d8d0>,
#  '多次': <gensim.models.keyedvectors.Vocab at 0x13be0d908>,
#  '進入': <gensim.models.keyedvectors.Vocab at 0x13be0d940>,
#  '發現': <gensim.models.keyedvectors.Vocab at 0x13be0d978>,
#  '當地': <gensim.models.keyedvectors.Vocab at 0x13be0d9b0>,
#  '活人': <gensim.models.keyedvectors.Vocab at 0x13be0d9e8>,
#  '亡者': <gensim.models.keyedvectors.Vocab at 0x13be0da20>,
#  '奇景': <gensim.models.keyedvectors.Vocab at 0x13be0da58>,
#  '這裡': <gensim.models.keyedvectors.Vocab at 0x13be0da90>,
#  '凝結': <gensim.models.keyedvectors.Vocab at 0x13be0dac8>,
#  '一般': <gensim.models.keyedvectors.Vocab at 0x13be0db00>,
#  '空氣': <gensim.models.keyedvectors.Vocab at 0x13be0db38>,
#  '墳墓': <gensim.models.keyedvectors.Vocab at 0x13be0db70>,
#  '緊鄰': <gensim.models.keyedvectors.Vocab at 0x13be0dba8>,
#  '距離': <gensim.models.keyedvectors.Vocab at 0x13be0dbe0>,
#  '家門口': <gensim.models.keyedvectors.Vocab at 0x13be0dc18>,
#  '推測': <gensim.models.keyedvectors.Vocab at 0x13be0dc50>,
#  '應該': <gensim.models.keyedvectors.Vocab at 0x13be0dc88>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x13be0dcc0>,
#  '建物': <gensim.models.keyedvectors.Vocab at 0x13be0dcf8>,
#  '如何': <gensim.models.keyedvectors.Vocab at 0x13be0dd30>,
#  '讓': <gensim.models.keyedvectors.Vocab at 0x13be0dd68>,
#  '感到': <gensim.models.keyedvectors.Vocab at 0x13be0dda0>,
#  '好奇': <gensim.models.keyedvectors.Vocab at 0x13be0ddd8>,
#  '因而': <gensim.models.keyedvectors.Vocab at 0x13be0de10>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x13be0de48>,
#  '為': <gensim.models.keyedvectors.Vocab at 0x13be0de80>,
#  '故事': <gensim.models.keyedvectors.Vocab at 0x13be0deb8>,
#  '背景': <gensim.models.keyedvectors.Vocab at 0x13be0def0>,
#  '地名': <gensim.models.keyedvectors.Vocab at 0x13be0df28>,
#  '拆遷': <gensim.models.keyedvectors.Vocab at 0x13be0df60>,
#  '過程': <gensim.models.keyedvectors.Vocab at 0x13be0df98>,
#  '根據': <gensim.models.keyedvectors.Vocab at 0x13be0dfd0>,
#  '真實': <gensim.models.keyedvectors.Vocab at 0x13be10048>,
#  '唯獨': <gensim.models.keyedvectors.Vocab at 0x13be10080>,
#  '人物': <gensim.models.keyedvectors.Vocab at 0x13be100b8>,
#  '2013': <gensim.models.keyedvectors.Vocab at 0x13be100f0>,
#  '出版': <gensim.models.keyedvectors.Vocab at 0x13be10128>,
#  '像是': <gensim.models.keyedvectors.Vocab at 0x13be10160>,
#  '尚未': <gensim.models.keyedvectors.Vocab at 0x13be10198>,
#  '拆': <gensim.models.keyedvectors.Vocab at 0x13be101d0>,
#  '聚集': <gensim.models.keyedvectors.Vocab at 0x13be10208>,
#  '各式': <gensim.models.keyedvectors.Vocab at 0x13be10240>,
#  '岡': <gensim.models.keyedvectors.Vocab at 0x13be10278>,
#  '回教': <gensim.models.keyedvectors.Vocab at 0x13be102b0>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x13be102e8>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x13be10320>,
#  '踩': <gensim.models.keyedvectors.Vocab at 0x13be10358>,
#  '腳底': <gensim.models.keyedvectors.Vocab at 0x13be10390>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x13be103c8>,
#  '更': <gensim.models.keyedvectors.Vocab at 0x13be10400>,
#  '著': <gensim.models.keyedvectors.Vocab at 0x13be10438>,
#  '清': <gensim.models.keyedvectors.Vocab at 0x13be10470>,
#  '日治': <gensim.models.keyedvectors.Vocab at 0x13be104a8>,
#  '時期': <gensim.models.keyedvectors.Vocab at 0x13be104e0>,
#  '以來': <gensim.models.keyedvectors.Vocab at 0x13be10518>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x13be10550>,
#  '專訪': <gensim.models.keyedvectors.Vocab at 0x13be10588>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x13be105c0>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x13be105f8>,
#  '說法': <gensim.models.keyedvectors.Vocab at 0x13be10630>,
#  '少說': <gensim.models.keyedvectors.Vocab at 0x13be10668>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x13be106a0>,
#  '2017': <gensim.models.keyedvectors.Vocab at 0x13be106d8>,
#  '一夕之間': <gensim.models.keyedvectors.Vocab at 0x13be10710>,
#  '拆毀': <gensim.models.keyedvectors.Vocab at 0x13be10748>,
#  '如今': <gensim.models.keyedvectors.Vocab at 0x13be10780>,
#  '森林公園': <gensim.models.keyedvectors.Vocab at 0x13be107b8>,
#  '當年': <gensim.models.keyedvectors.Vocab at 0x13be107f0>,
#  '書': <gensim.models.keyedvectors.Vocab at 0x13be10828>,
#  '中以': <gensim.models.keyedvectors.Vocab at 0x13be10860>,
#  '想像': <gensim.models.keyedvectors.Vocab at 0x13be10898>,
#  '寫道': <gensim.models.keyedvectors.Vocab at 0x13be108d0>,
#  '想不到': <gensim.models.keyedvectors.Vocab at 0x13be10908>,
#  '真': <gensim.models.keyedvectors.Vocab at 0x13be10940>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x13be10978>,
#  '再度': <gensim.models.keyedvectors.Vocab at 0x13be109b0>,
#  '內容': <gensim.models.keyedvectors.Vocab at 0x13be109e8>,
#  '新增': <gensim.models.keyedvectors.Vocab at 0x13be10a20>,
#  '過去': <gensim.models.keyedvectors.Vocab at 0x13be10a58>,
#  '田野': <gensim.models.keyedvectors.Vocab at 0x13be10a90>,
#  '調查': <gensim.models.keyedvectors.Vocab at 0x13be10ac8>,
#  '拍': <gensim.models.keyedvectors.Vocab at 0x13be10b00>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x13be10b38>,
#  '鮮少': <gensim.models.keyedvectors.Vocab at 0x13be10b70>,
#  '史料': <gensim.models.keyedvectors.Vocab at 0x13be10ba8>,
#  '因為': <gensim.models.keyedvectors.Vocab at 0x13be10be0>,
#  '人會': <gensim.models.keyedvectors.Vocab at 0x13be10c18>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x13be10c50>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x13be10c88>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x13be10cc0>,
#  '證明': <gensim.models.keyedvectors.Vocab at 0x13be10cf8>,
#  '否則': <gensim.models.keyedvectors.Vocab at 0x13be10d30>,
#  '傳說': <gensim.models.keyedvectors.Vocab at 0x13be10d68>,
#  '後來': <gensim.models.keyedvectors.Vocab at 0x13be10da0>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x13be10dd8>,
#  '讀': <gensim.models.keyedvectors.Vocab at 0x13be10e10>,
#  '感觸': <gensim.models.keyedvectors.Vocab at 0x13be10e48>,
#  '很深': <gensim.models.keyedvectors.Vocab at 0x13be10e80>,
#  '近期': <gensim.models.keyedvectors.Vocab at 0x13be10eb8>,
#  '辦': <gensim.models.keyedvectors.Vocab at 0x13be10ef0>,
#  '座談': <gensim.models.keyedvectors.Vocab at 0x13be10f28>,
#  '網路上': <gensim.models.keyedvectors.Vocab at 0x13be10f60>,
#  '搜尋': <gensim.models.keyedvectors.Vocab at 0x13be10f98>,
#  '年輕': <gensim.models.keyedvectors.Vocab at 0x13be10fd0>,
#  'Youtuber': <gensim.models.keyedvectors.Vocab at 0x13be15048>,
#  '夜遊': <gensim.models.keyedvectors.Vocab at 0x13be15080>,
#  '年輕人': <gensim.models.keyedvectors.Vocab at 0x13be150b8>,
#  '眼裡': <gensim.models.keyedvectors.Vocab at 0x13be150f0>,
#  '有些': <gensim.models.keyedvectors.Vocab at 0x13be15128>,
#  '感慨': <gensim.models.keyedvectors.Vocab at 0x13be15160>,
#  '通常': <gensim.models.keyedvectors.Vocab at 0x13be15198>,
#  '幾百年': <gensim.models.keyedvectors.Vocab at 0x13be151d0>,
#  '以前': <gensim.models.keyedvectors.Vocab at 0x13be15208>,
#  '變化': <gensim.models.keyedvectors.Vocab at 0x13be15240>,
#  '不過': <gensim.models.keyedvectors.Vocab at 0x13be15278>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x13be152b0>,
#  '十年': <gensim.models.keyedvectors.Vocab at 0x13be152e8>,
#  '之間': <gensim.models.keyedvectors.Vocab at 0x13be15320>,
#  '寫實': <gensim.models.keyedvectors.Vocab at 0x13be15358>,
#  '裡': <gensim.models.keyedvectors.Vocab at 0x13be15390>,
#  '描繪': <gensim.models.keyedvectors.Vocab at 0x13be153c8>,
#  '傳奇': <gensim.models.keyedvectors.Vocab at 0x13be15400>,
#  '創辦人': <gensim.models.keyedvectors.Vocab at 0x13be15438>,
#  '曾': <gensim.models.keyedvectors.Vocab at 0x13be15470>,
#  '這本': <gensim.models.keyedvectors.Vocab at 0x13be154a8>,
#  '想到': <gensim.models.keyedvectors.Vocab at 0x13be154e0>,
#  '百年': <gensim.models.keyedvectors.Vocab at 0x13be15518>,
#  '媽媽': <gensim.models.keyedvectors.Vocab at 0x13be15550>,
#  '常': <gensim.models.keyedvectors.Vocab at 0x13be15588>,
#  '一些': <gensim.models.keyedvectors.Vocab at 0x13be155c0>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x13be155f8>,
#  '有點': <gensim.models.keyedvectors.Vocab at 0x13be15630>,
#  '謊言': <gensim.models.keyedvectors.Vocab at 0x13be15668>,
#  '給他': <gensim.models.keyedvectors.Vocab at 0x13be156a0>,
#  '聽': <gensim.models.keyedvectors.Vocab at 0x13be156d8>,
#  '小時候': <gensim.models.keyedvectors.Vocab at 0x13be15710>,
#  '愛哭': <gensim.models.keyedvectors.Vocab at 0x13be15748>,
#  '便': <gensim.models.keyedvectors.Vocab at 0x13be15780>,
#  '恐嚇': <gensim.models.keyedvectors.Vocab at 0x13be157b8>,
#  '眼淚': <gensim.models.keyedvectors.Vocab at 0x13be157f0>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x13be15828>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x13be15860>,
#  '相信': <gensim.models.keyedvectors.Vocab at 0x13be15898>,
#  '他用': <gensim.models.keyedvectors.Vocab at 0x13be158d0>,
#  '衛生紙': <gensim.models.keyedvectors.Vocab at 0x13be15908>,
#  '擦': <gensim.models.keyedvectors.Vocab at 0x13be15940>,
#  '並且': <gensim.models.keyedvectors.Vocab at 0x13be15978>,
#  '陽台': <gensim.models.keyedvectors.Vocab at 0x13be159b0>,
#  '吹': <gensim.models.keyedvectors.Vocab at 0x13be159e8>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x13be15a20>,
#  '整晚': <gensim.models.keyedvectors.Vocab at 0x13be15a58>,
#  '血': <gensim.models.keyedvectors.Vocab at 0x13be15a90>,
#  '顏色': <gensim.models.keyedvectors.Vocab at 0x13be15ac8>,
#  '隔天': <gensim.models.keyedvectors.Vocab at 0x13be15b00>,
#  '醒來': <gensim.models.keyedvectors.Vocab at 0x13be15b38>,
#  '果真': <gensim.models.keyedvectors.Vocab at 0x13be15b70>,
#  '變紅': <gensim.models.keyedvectors.Vocab at 0x13be15ba8>,
#  '嚇得': <gensim.models.keyedvectors.Vocab at 0x13be15be0>,
#  '再也': <gensim.models.keyedvectors.Vocab at 0x13be15c18>,
#  '哭': <gensim.models.keyedvectors.Vocab at 0x13be15c50>,
#  '長大': <gensim.models.keyedvectors.Vocab at 0x13be15c88>,
#  '半夜': <gensim.models.keyedvectors.Vocab at 0x13be15cc0>,
#  '滴': <gensim.models.keyedvectors.Vocab at 0x13be15cf8>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x13be15d30>,
#  '火車': <gensim.models.keyedvectors.Vocab at 0x13be15d68>,
#  '吵鬧': <gensim.models.keyedvectors.Vocab at 0x13be15da0>,
#  '丟到': <gensim.models.keyedvectors.Vocab at 0x13be15dd8>,
#  '鐵軌': <gensim.models.keyedvectors.Vocab at 0x13be15e10>,
#  '壓': <gensim.models.keyedvectors.Vocab at 0x13be15e48>,
#  '爆米花': <gensim.models.keyedvectors.Vocab at 0x13be15e80>,
#  '親眼': <gensim.models.keyedvectors.Vocab at 0x13be15eb8>,
#  '見證': <gensim.models.keyedvectors.Vocab at 0x13be15ef0>,
#  '幾小時': <gensim.models.keyedvectors.Vocab at 0x13be15f28>,
#  '眼睛': <gensim.models.keyedvectors.Vocab at 0x13be15f60>,
#  '緊盯': <gensim.models.keyedvectors.Vocab at 0x13be15f98>,
#  '果然': <gensim.models.keyedvectors.Vocab at 0x13be15fd0>,
#  '不吵': <gensim.models.keyedvectors.Vocab at 0x13be18048>,
#  '鬧': <gensim.models.keyedvectors.Vocab at 0x13be18080>,
#  '我會': <gensim.models.keyedvectors.Vocab at 0x13be180b8>,
#  '堅信': <gensim.models.keyedvectors.Vocab at 0x13be180f0>,
#  '所有人': <gensim.models.keyedvectors.Vocab at 0x13be18128>,
#  '我講': <gensim.models.keyedvectors.Vocab at 0x13be18160>,
#  '荒謬': <gensim.models.keyedvectors.Vocab at 0x13be18198>,
#  '也許': <gensim.models.keyedvectors.Vocab at 0x13be181d0>,
#  '他講': <gensim.models.keyedvectors.Vocab at 0x13be18208>,
#  '一件': <gensim.models.keyedvectors.Vocab at 0x13be18240>,
#  '選擇': <gensim.models.keyedvectors.Vocab at 0x13be18278>,
#  '或許': <gensim.models.keyedvectors.Vocab at 0x13be182b0>,
#  '成為': <gensim.models.keyedvectors.Vocab at 0x13be182e8>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x13be18320>,
#  '想像力': <gensim.models.keyedvectors.Vocab at 0x13be18358>,
#  '豐富': <gensim.models.keyedvectors.Vocab at 0x13be18390>,
#  '就連': <gensim.models.keyedvectors.Vocab at 0x13be183c8>,
#  '妹妹': <gensim.models.keyedvectors.Vocab at 0x13be18400>,
#  '覺得': <gensim.models.keyedvectors.Vocab at 0x13be18438>,
#  '所有': <gensim.models.keyedvectors.Vocab at 0x13be18470>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x13be184a8>,
#  '回到': <gensim.models.keyedvectors.Vocab at 0x13be184e0>,
#  '裡的': <gensim.models.keyedvectors.Vocab at 0x13be18518>,
#  '角色': <gensim.models.keyedvectors.Vocab at 0x13be18550>,
#  '欺騙': <gensim.models.keyedvectors.Vocab at 0x13be18588>,
#  '悲傷': <gensim.models.keyedvectors.Vocab at 0x13be185c0>,
#  '才能': <gensim.models.keyedvectors.Vocab at 0x13be185f8>,
#  '留下': <gensim.models.keyedvectors.Vocab at 0x13be18630>,
#  '美好': <gensim.models.keyedvectors.Vocab at 0x13be18668>,
#  '最後': <gensim.models.keyedvectors.Vocab at 0x13be186a0>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x13be186d8>,
#  '溫暖': <gensim.models.keyedvectors.Vocab at 0x13be18710>,
#  '讀者': <gensim.models.keyedvectors.Vocab at 0x13be18748>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x13be18780>,
#  '從中': <gensim.models.keyedvectors.Vocab at 0x13be187b8>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x13be187f0>,
#  '一塊': <gensim.models.keyedvectors.Vocab at 0x13be18828>,
#  '彌補': <gensim.models.keyedvectors.Vocab at 0x13be18860>,
#  '心裡': <gensim.models.keyedvectors.Vocab at 0x13be18898>,
#  '空缺': <gensim.models.keyedvectors.Vocab at 0x13be188d0>,
#  '舉辦': <gensim.models.keyedvectors.Vocab at 0x13be18908>,
#  '新書': <gensim.models.keyedvectors.Vocab at 0x13be18940>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x13be18978>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x13be189b0>,
#  '樂團': <gensim.models.keyedvectors.Vocab at 0x13be189e8>,
#  '五月天': <gensim.models.keyedvectors.Vocab at 0x13be18a20>,
#  '石頭': <gensim.models.keyedvectors.Vocab at 0x13be18a58>,
#  '誠品': <gensim.models.keyedvectors.Vocab at 0x13be18a90>,
#  '松': <gensim.models.keyedvectors.Vocab at 0x13be18ac8>,
#  '菸': <gensim.models.keyedvectors.Vocab at 0x13be18b00>,
#  '店': <gensim.models.keyedvectors.Vocab at 0x13be18b38>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x13be18b70>,
#  '音樂': <gensim.models.keyedvectors.Vocab at 0x13be18ba8>,
#  '藝術': <gensim.models.keyedvectors.Vocab at 0x13be18be0>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x13be18c18>,
#  '中山大學': <gensim.models.keyedvectors.Vocab at 0x13be18c50>,
#  '系': <gensim.models.keyedvectors.Vocab at 0x13be18c88>,
#  '助理': <gensim.models.keyedvectors.Vocab at 0x13be18cc0>,
#  '教授': <gensim.models.keyedvectors.Vocab at 0x13be18cf8>,
#  'SOGO': <gensim.models.keyedvectors.Vocab at 0x13be18d30>,
#  '書室': <gensim.models.keyedvectors.Vocab at 0x13be18d68>,
#  '對談': <gensim.models.keyedvectors.Vocab at 0x13be18da0>,
#  '王淑芬': <gensim.models.keyedvectors.Vocab at 0x13be18dd8>,
#  '26': <gensim.models.keyedvectors.Vocab at 0x13be18e10>,
#  '促': <gensim.models.keyedvectors.Vocab at 0x13be18e48>,
#  '韓國': <gensim.models.keyedvectors.Vocab at 0x13be18e80>,
#  '瑜': <gensim.models.keyedvectors.Vocab at 0x13be18eb8>,
#  '辭職': <gensim.models.keyedvectors.Vocab at 0x13be18ef0>,
#  '高市': <gensim.models.keyedvectors.Vocab at 0x13be18f28>,
#  '藍綠': <gensim.models.keyedvectors.Vocab at 0x13be18f60>,
#  '議員': <gensim.models.keyedvectors.Vocab at 0x13be18f98>,
#  '爆': <gensim.models.keyedvectors.Vocab at 0x13be18fd0>,
#  '肢體衝突': <gensim.models.keyedvectors.Vocab at 0x13be1b048>,
#  '議會': <gensim.models.keyedvectors.Vocab at 0x13be1b080>,
#  '今天': <gensim.models.keyedvectors.Vocab at 0x13be1b0b8>,
#  '進行': <gensim.models.keyedvectors.Vocab at 0x13be1b0f0>,
#  '市政': <gensim.models.keyedvectors.Vocab at 0x13be1b128>,
#  '施政報告': <gensim.models.keyedvectors.Vocab at 0x13be1b160>,
#  '質詢': <gensim.models.keyedvectors.Vocab at 0x13be1b198>,
#  '民進黨': <gensim.models.keyedvectors.Vocab at 0x13be1b1d0>,
#  '鄭孟': <gensim.models.keyedvectors.Vocab at 0x13be1b208>,
#  '洳': <gensim.models.keyedvectors.Vocab at 0x13be1b240>,
#  '要求': <gensim.models.keyedvectors.Vocab at 0x13be1b278>,
#  '市長': <gensim.models.keyedvectors.Vocab at 0x13be1b2b0>,
#  '允諾': <gensim.models.keyedvectors.Vocab at 0x13be1b2e8>,
#  '總': <gensim.models.keyedvectors.Vocab at 0x13be1b320>,
#  '不要': <gensim.models.keyedvectors.Vocab at 0x13be1b358>,
#  '請假': <gensim.models.keyedvectors.Vocab at 0x13be1b390>,
#  '選舉': <gensim.models.keyedvectors.Vocab at 0x13be1b3c8>,
#  '遭': <gensim.models.keyedvectors.Vocab at 0x13be1b400>,
#  '包圍': <gensim.models.keyedvectors.Vocab at 0x13be1b438>,
#  '擋': <gensim.models.keyedvectors.Vocab at 0x13be1b470>,
#  '肢體': <gensim.models.keyedvectors.Vocab at 0x13be1b4a8>,
#  '衝突': <gensim.models.keyedvectors.Vocab at 0x13be1b4e0>,
#  '第二次': <gensim.models.keyedvectors.Vocab at 0x13be1b518>,
#  '定期': <gensim.models.keyedvectors.Vocab at 0x13be1b550>,
#  '大會': <gensim.models.keyedvectors.Vocab at 0x13be1b588>,
#  '登場': <gensim.models.keyedvectors.Vocab at 0x13be1b5c0>,
#  '團': <gensim.models.keyedvectors.Vocab at 0x13be1b5f8>,
#  '聯合': <gensim.models.keyedvectors.Vocab at 0x13be1b630>,
#  '就要': <gensim.models.keyedvectors.Vocab at 0x13be1b668>,
#  '保證': <gensim.models.keyedvectors.Vocab at 0x13be1b6a0>,
#  '能否': <gensim.models.keyedvectors.Vocab at 0x13be1b6d8>,
#  '期間': <gensim.models.keyedvectors.Vocab at 0x13be1b710>,
#  '答覆': <gensim.models.keyedvectors.Vocab at 0x13be1b748>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x13be1b780>,
#  '規劃': <gensim.models.keyedvectors.Vocab at 0x13be1b7b8>,
#  '有要': <gensim.models.keyedvectors.Vocab at 0x13be1b7f0>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x13be1b828>,
#  '報告': <gensim.models.keyedvectors.Vocab at 0x13be1b860>,
#  '拿出': <gensim.models.keyedvectors.Vocab at 0x13be1b898>,
#  '要給': <gensim.models.keyedvectors.Vocab at 0x13be1b8d0>,
#  '雙方': <gensim.models.keyedvectors.Vocab at 0x13be1b908>,
#  '爆發': <gensim.models.keyedvectors.Vocab at 0x13be1b940>,
#  '議': <gensim.models.keyedvectors.Vocab at 0x13be1b978>,
#  '員': <gensim.models.keyedvectors.Vocab at 0x13be1b9b0>,
#  '推擠': <gensim.models.keyedvectors.Vocab at 0x13be1b9e8>,
#  '不停': <gensim.models.keyedvectors.Vocab at 0x13be1ba20>,
#  '前後': <gensim.models.keyedvectors.Vocab at 0x13be1ba58>,
#  '分鐘': <gensim.models.keyedvectors.Vocab at 0x13be1ba90>,
#  '會議': <gensim.models.keyedvectors.Vocab at 0x13be1bac8>,
#  '56': <gensim.models.keyedvectors.Vocab at 0x13be1bb00>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x13be1bb38>,
#  '中斷': <gensim.models.keyedvectors.Vocab at 0x13be1bb70>,
#  '休息': <gensim.models.keyedvectors.Vocab at 0x13be1bba8>,
#  '及': <gensim.models.keyedvectors.Vocab at 0x13be1bbe0>,
#  '官員': <gensim.models.keyedvectors.Vocab at 0x13be1bc18>,
#  '一度': <gensim.models.keyedvectors.Vocab at 0x13be1bc50>,
#  '走出': <gensim.models.keyedvectors.Vocab at 0x13be1bc88>,
#  '休': <gensim.models.keyedvectors.Vocab at 0x13be1bcc0>,
#  '息': <gensim.models.keyedvectors.Vocab at 0x13be1bcf8>,
#  '直到': <gensim.models.keyedvectors.Vocab at 0x13be1bd30>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x13be1bd68>,
#  '恢復': <gensim.models.keyedvectors.Vocab at 0x13be1bda0>,
#  '張芷瑄': <gensim.models.keyedvectors.Vocab at 0x13be1bdd8>,
#  '幹': <gensim.models.keyedvectors.Vocab at 0x13be1be10>,
#  'DPP': <gensim.models.keyedvectors.Vocab at 0x13be1be48>,
#  '真是': <gensim.models.keyedvectors.Vocab at 0x13be1be80>,
#  '廢': <gensim.models.keyedvectors.Vocab at 0x13be1beb8>,
#  '好好': <gensim.models.keyedvectors.Vocab at 0x13be1bef0>,
#  '草包': <gensim.models.keyedvectors.Vocab at 0x13be1bf28>,
#  '搞': <gensim.models.keyedvectors.Vocab at 0x13be1bf60>,
#  '一堆': <gensim.models.keyedvectors.Vocab at 0x13be1bf98>,
#  '這下': <gensim.models.keyedvectors.Vocab at 0x13be1bfd0>,
#  '還在': <gensim.models.keyedvectors.Vocab at 0x13be1f048>,
#  '那邊': <gensim.models.keyedvectors.Vocab at 0x13be1f080>,
#  '垃圾': <gensim.models.keyedvectors.Vocab at 0x13be1f0b8>,
#  '鱉': <gensim.models.keyedvectors.Vocab at 0x13be1f0f0>,
#  '殺': <gensim.models.keyedvectors.Vocab at 0x13be1f128>,
#  '流血': <gensim.models.keyedvectors.Vocab at 0x13be1f160>,
#  '第一眼': <gensim.models.keyedvectors.Vocab at 0x13be1f198>,
#  '明白': <gensim.models.keyedvectors.Vocab at 0x13be1f1d0>,
#  '肥宅': <gensim.models.keyedvectors.Vocab at 0x13be1f208>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x13be1f240>,
#  '妹子': <gensim.models.keyedvectors.Vocab at 0x13be1f278>,
#  'ㄉ': <gensim.models.keyedvectors.Vocab at 0x13be1f2b0>,
#  '表情': <gensim.models.keyedvectors.Vocab at 0x13be1f2e8>,
#  '警察局': <gensim.models.keyedvectors.Vocab at 0x13be1f320>,
#  'ㄌ': <gensim.models.keyedvectors.Vocab at 0x13be1f358>,
#  '女森': <gensim.models.keyedvectors.Vocab at 0x13be1f390>,
#  '該': <gensim.models.keyedvectors.Vocab at 0x13be1f3c8>,
#  '怎麼辦': <gensim.models.keyedvectors.Vocab at 0x13be1f400>,
#  'TVBS': <gensim.models.keyedvectors.Vocab at 0x13be1f438>,
#  '芊': <gensim.models.keyedvectors.Vocab at 0x13be1f470>,
#  '可愛': <gensim.models.keyedvectors.Vocab at 0x13be1f4a8>,
#  '女': <gensim.models.keyedvectors.Vocab at 0x13be1f4e0>,
#  '高校': <gensim.models.keyedvectors.Vocab at 0x13be1f518>,
#  '生': <gensim.models.keyedvectors.Vocab at 0x13be1f550>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x13be1f588>,
#  '強': <gensim.models.keyedvectors.Vocab at 0x13be1f5c0>,
#  '出爐': <gensim.models.keyedvectors.Vocab at 0x13be1f5f8>,
#  '酸': <gensim.models.keyedvectors.Vocab at 0x13be1f630>,
#  '素質': <gensim.models.keyedvectors.Vocab at 0x13be1f668>,
#  '差': <gensim.models.keyedvectors.Vocab at 0x13be1f6a0>,
#  '時尚': <gensim.models.keyedvectors.Vocab at 0x13be1f6d8>,
#  '娛樂': <gensim.models.keyedvectors.Vocab at 0x13be1f710>,
#  '網站': <gensim.models.keyedvectors.Vocab at 0x13be1f748>,
#  '每年': <gensim.models.keyedvectors.Vocab at 0x13be1f780>,
#  '選拔賽': <gensim.models.keyedvectors.Vocab at 0x13be1f7b8>,
#  '活動': <gensim.models.keyedvectors.Vocab at 0x13be1f7f0>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x13be1f828>,
#  '邁入': <gensim.models.keyedvectors.Vocab at 0x13be1f860>,
#  '第': <gensim.models.keyedvectors.Vocab at 0x13be1f898>,
#  '屆': <gensim.models.keyedvectors.Vocab at 0x13be1f8d0>,
#  '經過': <gensim.models.keyedvectors.Vocab at 0x13be1f908>,
#  '層層': <gensim.models.keyedvectors.Vocab at 0x13be1f940>,
#  '賽制': <gensim.models.keyedvectors.Vocab at 0x13be1f978>,
#  '嚴格': <gensim.models.keyedvectors.Vocab at 0x13be1f9b0>,
#  '篩選': <gensim.models.keyedvectors.Vocab at 0x13be1f9e8>,
#  '終於': <gensim.models.keyedvectors.Vocab at 0x13be1fa20>,
#  '公布': <gensim.models.keyedvectors.Vocab at 0x13be1fa58>,
#  '入圍': <gensim.models.keyedvectors.Vocab at 0x13be1fa90>,
#  '對於': <gensim.models.keyedvectors.Vocab at 0x13be1fac8>,
#  '強的': <gensim.models.keyedvectors.Vocab at 0x13be1fb00>,
#  '結果': <gensim.models.keyedvectors.Vocab at 0x13be1fb38>,
#  '許多': <gensim.models.keyedvectors.Vocab at 0x13be1fb70>,
#  '並不': <gensim.models.keyedvectors.Vocab at 0x13be1fba8>,
#  '買單': <gensim.models.keyedvectors.Vocab at 0x13be1fbe0>,
#  '參賽者': <gensim.models.keyedvectors.Vocab at 0x13be1fc18>,
#  '太差': <gensim.models.keyedvectors.Vocab at 0x13be1fc50>,
#  '令人': <gensim.models.keyedvectors.Vocab at 0x13be1fc88>,
#  '失望': <gensim.models.keyedvectors.Vocab at 0x13be1fcc0>,
#  '綜合': <gensim.models.keyedvectors.Vocab at 0x13be1fcf8>,
#  '日媒': <gensim.models.keyedvectors.Vocab at 0x13be1fd30>,
#  '報導': <gensim.models.keyedvectors.Vocab at 0x13be1fd68>,
#  '女子': <gensim.models.keyedvectors.Vocab at 0x13be1fda0>,
#  '選拔': <gensim.models.keyedvectors.Vocab at 0x13be1fdd8>,
#  '吸引': <gensim.models.keyedvectors.Vocab at 0x13be1fe10>,
#  '眾多': <gensim.models.keyedvectors.Vocab at 0x13be1fe48>,
#  '符合': <gensim.models.keyedvectors.Vocab at 0x13be1fe80>,
#  '資格': <gensim.models.keyedvectors.Vocab at 0x13be1feb8>,
#  '報名': <gensim.models.keyedvectors.Vocab at 0x13be1fef0>,
#  '參加': <gensim.models.keyedvectors.Vocab at 0x13be1ff28>,
#  '例外': <gensim.models.keyedvectors.Vocab at 0x13be1ff60>,
#  '們': <gensim.models.keyedvectors.Vocab at 0x13be1ff98>,
#  '初': <gensim.models.keyedvectors.Vocab at 0x13be1ffd0>,
#  '賽': <gensim.models.keyedvectors.Vocab at 0x13be23048>,
#  '分別': <gensim.models.keyedvectors.Vocab at 0x13be23080>,
#  '關東': <gensim.models.keyedvectors.Vocab at 0x13be230b8>,
#  '關西': <gensim.models.keyedvectors.Vocab at 0x13be230f0>,
#  '中部': <gensim.models.keyedvectors.Vocab at 0x13be23128>,
#  '四國': <gensim.models.keyedvectors.Vocab at 0x13be23160>,
#  '九州': <gensim.models.keyedvectors.Vocab at 0x13be23198>,
#  '東北': <gensim.models.keyedvectors.Vocab at 0x13be231d0>,
#  '區域': <gensim.models.keyedvectors.Vocab at 0x13be23208>,
#  '網路': <gensim.models.keyedvectors.Vocab at 0x13be23240>,
#  '得票': <gensim.models.keyedvectors.Vocab at 0x13be23278>,
#  '留言': <gensim.models.keyedvectors.Vocab at 0x13be232b0>,
#  '數': <gensim.models.keyedvectors.Vocab at 0x13be232e8>,
#  '點': <gensim.models.keyedvectors.Vocab at 0x13be23320>,
#  '讚': <gensim.models.keyedvectors.Vocab at 0x13be23358>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x13be23390>,
#  '數據': <gensim.models.keyedvectors.Vocab at 0x13be233c8>,
#  '條件': <gensim.models.keyedvectors.Vocab at 0x13be23400>,
#  '各區': <gensim.models.keyedvectors.Vocab at 0x13be23438>,
#  '選出': <gensim.models.keyedvectors.Vocab at 0x13be23470>,
#  '最高': <gensim.models.keyedvectors.Vocab at 0x13be234a8>,
#  '票': <gensim.models.keyedvectors.Vocab at 0x13be234e0>,
#  '選手': <gensim.models.keyedvectors.Vocab at 0x13be23518>,
#  '晉級': <gensim.models.keyedvectors.Vocab at 0x13be23550>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x13be23588>,
#  '官方': <gensim.models.keyedvectors.Vocab at 0x13be235c0>,
#  '挑選': <gensim.models.keyedvectors.Vocab at 0x13be235f8>,
#  '出色': <gensim.models.keyedvectors.Vocab at 0x13be23630>,
#  '2019': <gensim.models.keyedvectors.Vocab at 0x13be23668>,
#  '年級': <gensim.models.keyedvectors.Vocab at 0x13be236a0>,
#  '冠軍': <gensim.models.keyedvectors.Vocab at 0x13be236d8>,
#  '共': <gensim.models.keyedvectors.Vocab at 0x13be23710>,
#  '剩下': <gensim.models.keyedvectors.Vocab at 0x13be23748>,
#  '淘汰': <gensim.models.keyedvectors.Vocab at 0x13be23780>,
#  '選': <gensim.models.keyedvectors.Vocab at 0x13be237b8>,
#  '藉由': <gensim.models.keyedvectors.Vocab at 0x13be237f0>,
#  '復活': <gensim.models.keyedvectors.Vocab at 0x13be23828>,
#  '搶奪': <gensim.models.keyedvectors.Vocab at 0x13be23860>,
#  '冠軍賽': <gensim.models.keyedvectors.Vocab at 0x13be23898>,
#  '因此': <gensim.models.keyedvectors.Vocab at 0x13be238d0>,
#  '百位': <gensim.models.keyedvectors.Vocab at 0x13be23908>,
#  '最終': <gensim.models.keyedvectors.Vocab at 0x13be23940>,
#  '只會': <gensim.models.keyedvectors.Vocab at 0x13be23978>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x13be239b0>,
#  '得以': <gensim.models.keyedvectors.Vocab at 0x13be239e8>,
#  '總冠軍': <gensim.models.keyedvectors.Vocab at 0x13be23a20>,
#  '爭奪': <gensim.models.keyedvectors.Vocab at 0x13be23a58>,
#  '稱號': <gensim.models.keyedvectors.Vocab at 0x13be23a90>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x13be23ac8>,
#  '這場': <gensim.models.keyedvectors.Vocab at 0x13be23b00>,
#  '比賽': <gensim.models.keyedvectors.Vocab at 0x13be23b38>,
#  '獲得': <gensim.models.keyedvectors.Vocab at 0x13be23b70>,
#  '將成': <gensim.models.keyedvectors.Vocab at 0x13be23ba8>,
#  '公關': <gensim.models.keyedvectors.Vocab at 0x13be23be0>,
#  '大使': <gensim.models.keyedvectors.Vocab at 0x13be23c18>,
#  '生涯': <gensim.models.keyedvectors.Vocab at 0x13be23c50>,
#  '擁有': <gensim.models.keyedvectors.Vocab at 0x13be23c88>,
#  '這份': <gensim.models.keyedvectors.Vocab at 0x13be23cc0>,
#  '殊榮': <gensim.models.keyedvectors.Vocab at 0x13be23cf8>,
#  '引起': <gensim.models.keyedvectors.Vocab at 0x13be23d30>,
#  '關注': <gensim.models.keyedvectors.Vocab at 0x13be23d68>,
#  '十分': <gensim.models.keyedvectors.Vocab at 0x13be23da0>,
#  '期待': <gensim.models.keyedvectors.Vocab at 0x13be23dd8>,
#  '大批': <gensim.models.keyedvectors.Vocab at 0x13be23e10>,
#  '狂酸': <gensim.models.keyedvectors.Vocab at 0x13be23e48>,
#  '這屆': <gensim.models.keyedvectors.Vocab at 0x13be23e80>,
#  '太低': <gensim.models.keyedvectors.Vocab at 0x13be23eb8>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x13be23ef0>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x13be23f28>,
#  '感覺': <gensim.models.keyedvectors.Vocab at 0x13be23f60>,
#  '鄰居': <gensim.models.keyedvectors.Vocab at 0x13be23f98>,
#  '發表': <gensim.models.keyedvectors.Vocab at 0x13be23fd0>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x13be26048>,
#  '看法': <gensim.models.keyedvectors.Vocab at 0x13be26080>,
#  '全都': <gensim.models.keyedvectors.Vocab at 0x13be260b8>,
#  '啊': <gensim.models.keyedvectors.Vocab at 0x13be260f0>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x13be26128>,
#  'と': <gensim.models.keyedvectors.Vocab at 0x13be26160>,
#  '男': <gensim.models.keyedvectors.Vocab at 0x13be26198>,
#  'が': <gensim.models.keyedvectors.Vocab at 0x13be261d0>,
#  '話': <gensim.models.keyedvectors.Vocab at 0x13be26208>,
#  'し': <gensim.models.keyedvectors.Vocab at 0x13be26240>,
#  'て': <gensim.models.keyedvectors.Vocab at 0x13be26278>,
#  'い': <gensim.models.keyedvectors.Vocab at 0x13be262b0>,
#  'ま': <gensim.models.keyedvectors.Vocab at 0x13be262e8>,
#  'す': <gensim.models.keyedvectors.Vocab at 0x13be26320>,
#  'な': <gensim.models.keyedvectors.Vocab at 0x13be26358>,
#  'を': <gensim.models.keyedvectors.Vocab at 0x13be26390>,
#  'く': <gensim.models.keyedvectors.Vocab at 0x13be263c8>,
#  'だ': <gensim.models.keyedvectors.Vocab at 0x13be26400>,
#  'さ': <gensim.models.keyedvectors.Vocab at 0x13be26438>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x13be26470>,
#  'こ': <gensim.models.keyedvectors.Vocab at 0x13be264a8>,
#  'ふ': <gensim.models.keyedvectors.Vocab at 0x13be264e0>,
#  'は': <gensim.models.keyedvectors.Vocab at 0x13be26518>,
#  'も': <gensim.models.keyedvectors.Vocab at 0x13be26550>,
#  'き': <gensim.models.keyedvectors.Vocab at 0x13be26588>,
#  'れ': <gensim.models.keyedvectors.Vocab at 0x13be265c0>,
#  'で': <gensim.models.keyedvectors.Vocab at 0x13be265f8>,
#  '╴': <gensim.models.keyedvectors.Vocab at 0x13be26630>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x13be26668>,
#  'ど': <gensim.models.keyedvectors.Vocab at 0x13be266a0>,
#  '欲': <gensim.models.keyedvectors.Vocab at 0x13be266d8>,
#  'か': <gensim.models.keyedvectors.Vocab at 0x13be26710>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x13be26748>,
#  '私': <gensim.models.keyedvectors.Vocab at 0x13be26780>,
#  'あ': <gensim.models.keyedvectors.Vocab at 0x13be267b8>,
#  'た': <gensim.models.keyedvectors.Vocab at 0x13be267f0>,
#  'セ': <gensim.models.keyedvectors.Vocab at 0x13be26828>,
#  'ッ': <gensim.models.keyedvectors.Vocab at 0x13be26860>,
#  'ク': <gensim.models.keyedvectors.Vocab at 0x13be26898>,
#  'ス': <gensim.models.keyedvectors.Vocab at 0x13be268d0>,
#  'C': <gensim.models.keyedvectors.Vocab at 0x13be26908>,
#  'お': <gensim.models.keyedvectors.Vocab at 0x13be26940>,
#  '何': <gensim.models.keyedvectors.Vocab at 0x13be26978>,
#  '出': <gensim.models.keyedvectors.Vocab at 0x13be269b0>,
#  'せ': <gensim.models.keyedvectors.Vocab at 0x13be269e8>,
#  'ん': <gensim.models.keyedvectors.Vocab at 0x13be26a20>,
#  'よ': <gensim.models.keyedvectors.Vocab at 0x13be26a58>,
#  'D': <gensim.models.keyedvectors.Vocab at 0x13be26a90>,
#  'め': <gensim.models.keyedvectors.Vocab at 0x13be26ac8>,
#  'ょ': <gensim.models.keyedvectors.Vocab at 0x13be26b00>,
#  'う': <gensim.models.keyedvectors.Vocab at 0x13be26b38>,
#  '民明': <gensim.models.keyedvectors.Vocab at 0x13be26b70>,
#  '書房': <gensim.models.keyedvectors.Vocab at 0x13be26ba8>,
#  '初級': <gensim.models.keyedvectors.Vocab at 0x13be26be0>,
#  '日文': <gensim.models.keyedvectors.Vocab at 0x13be26c18>,
#  '新聞網': <gensim.models.keyedvectors.Vocab at 0x13be26c50>,
#  '北京': <gensim.models.keyedvectors.Vocab at 0x13be26c88>,
#  '至': <gensim.models.keyedvectors.Vocab at 0x13be26cc0>,
#  '高鐵': <gensim.models.keyedvectors.Vocab at 0x13be26cf8>,
#  '先期': <gensim.models.keyedvectors.Vocab at 0x13be26d30>,
#  '工程': <gensim.models.keyedvectors.Vocab at 0x13be26d68>,
#  '平潭': <gensim.models.keyedvectors.Vocab at 0x13be26da0>,
#  '大橋': <gensim.models.keyedvectors.Vocab at 0x13be26dd8>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x13be26e10>,
#  '貫通': <gensim.models.keyedvectors.Vocab at 0x13be26e48>,
#  '大陸': <gensim.models.keyedvectors.Vocab at 0x13be26e80>,
#  '十三': <gensim.models.keyedvectors.Vocab at 0x13be26eb8>,
#  '2016': <gensim.models.keyedvectors.Vocab at 0x13be26ef0>,
#  '2020': <gensim.models.keyedvectors.Vocab at 0x13be26f28>,
#  '提出': <gensim.models.keyedvectors.Vocab at 0x13be26f60>,
#  '建設': <gensim.models.keyedvectors.Vocab at 0x13be26f98>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x13be26fd0>,
#  '鐵路線': <gensim.models.keyedvectors.Vocab at 0x13be29048>,
#  '儘管': <gensim.models.keyedvectors.Vocab at 0x13be29080>,
#  '此一': <gensim.models.keyedvectors.Vocab at 0x13be290b8>,
#  '構想': <gensim.models.keyedvectors.Vocab at 0x13be290f0>,
#  '天方夜譚': <gensim.models.keyedvectors.Vocab at 0x13be29128>,
#  '仍': <gensim.models.keyedvectors.Vocab at 0x13be29160>,
#  '持續': <gensim.models.keyedvectors.Vocab at 0x13be29198>,
#  '推進': <gensim.models.keyedvectors.Vocab at 0x13be291d0>,
#  '最新': <gensim.models.keyedvectors.Vocab at 0x13be29208>,
#  '消': <gensim.models.keyedvectors.Vocab at 0x13be29240>,
#  '京台': <gensim.models.keyedvectors.Vocab at 0x13be29278>,
#  '前期': <gensim.models.keyedvectors.Vocab at 0x13be292b0>,
#  '海峽': <gensim.models.keyedvectors.Vocab at 0x13be292e8>,
#  '公鐵': <gensim.models.keyedvectors.Vocab at 0x13be29320>,
#  '已於': <gensim.models.keyedvectors.Vocab at 0x13be29358>,
#  '合龍': <gensim.models.keyedvectors.Vocab at 0x13be29390>,
#  '合肥': <gensim.models.keyedvectors.Vocab at 0x13be293c8>,
#  '福州': <gensim.models.keyedvectors.Vocab at 0x13be29400>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x13be29438>,
#  '28': <gensim.models.keyedvectors.Vocab at 0x13be29470>,
#  '通車': <gensim.models.keyedvectors.Vocab at 0x13be294a8>,
#  '按': <gensim.models.keyedvectors.Vocab at 0x13be294e0>,
#  '部分': <gensim.models.keyedvectors.Vocab at 0x13be29518>,
#  '將由': <gensim.models.keyedvectors.Vocab at 0x13be29550>,
#  '預留': <gensim.models.keyedvectors.Vocab at 0x13be29588>,
#  '通道': <gensim.models.keyedvectors.Vocab at 0x13be295c0>,
#  '計畫': <gensim.models.keyedvectors.Vocab at 0x13be295f8>,
#  '經': <gensim.models.keyedvectors.Vocab at 0x13be29630>,
#  '直通': <gensim.models.keyedvectors.Vocab at 0x13be29668>,
#  '桃園': <gensim.models.keyedvectors.Vocab at 0x13be296a0>,
#  '當中': <gensim.models.keyedvectors.Vocab at 0x13be296d8>,
#  '連接': <gensim.models.keyedvectors.Vocab at 0x13be29710>,
#  '關鍵': <gensim.models.keyedvectors.Vocab at 0x13be29748>,
#  '新華社': <gensim.models.keyedvectors.Vocab at 0x13be29780>,
#  '隨著': <gensim.models.keyedvectors.Vocab at 0x13be297b8>,
#  '公尺': <gensim.models.keyedvectors.Vocab at 0x13be297f0>,
#  '重': <gensim.models.keyedvectors.Vocab at 0x13be29828>,
#  '噸': <gensim.models.keyedvectors.Vocab at 0x13be29860>,
#  '鋼': <gensim.models.keyedvectors.Vocab at 0x13be29898>,
#  '住': <gensim.models.keyedvectors.Vocab at 0x13be298d0>,
#  '精確': <gensim.models.keyedvectors.Vocab at 0x13be29908>,
#  '固定': <gensim.models.keyedvectors.Vocab at 0x13be29940>,
#  '到位': <gensim.models.keyedvectors.Vocab at 0x13be29978>,
#  '總長': <gensim.models.keyedvectors.Vocab at 0x13be299b0>,
#  '公里': <gensim.models.keyedvectors.Vocab at 0x13be299e8>,
#  '平': <gensim.models.keyedvectors.Vocab at 0x13be29a20>,
#  '潭': <gensim.models.keyedvectors.Vocab at 0x13be29a58>,
#  '正式': <gensim.models.keyedvectors.Vocab at 0x13be29a90>,
#  '稱': <gensim.models.keyedvectors.Vocab at 0x13be29ac8>,
#  '鐵路': <gensim.models.keyedvectors.Vocab at 0x13be29b00>,
#  '控': <gensim.models.keyedvectors.Vocab at 0x13be29b38>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x13be29b70>,
#  '於': <gensim.models.keyedvectors.Vocab at 0x13be29ba8>,
#  '區': <gensim.models.keyedvectors.Vocab at 0x13be29be0>,
#  '小島': <gensim.models.keyedvectors.Vocab at 0x13be29c18>,
#  '抵達': <gensim.models.keyedvectors.Vocab at 0x13be29c50>,
#  '中國': <gensim.models.keyedvectors.Vocab at 0x13be29c88>,
#  '第五': <gensim.models.keyedvectors.Vocab at 0x13be29cc0>,
#  '大島': <gensim.models.keyedvectors.Vocab at 0x13be29cf8>,
#  '層': <gensim.models.keyedvectors.Vocab at 0x13be29d30>,
#  '設計': <gensim.models.keyedvectors.Vocab at 0x13be29d68>,
#  '時速': <gensim.models.keyedvectors.Vocab at 0x13be29da0>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x13be29dd8>,
#  '六': <gensim.models.keyedvectors.Vocab at 0x13be29e10>,
#  '車道': <gensim.models.keyedvectors.Vocab at 0x13be29e48>,
#  '高速公路': <gensim.models.keyedvectors.Vocab at 0x13be29e80>,
#  '下層': <gensim.models.keyedvectors.Vocab at 0x13be29eb8>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x13be29ef0>,
#  '據': <gensim.models.keyedvectors.Vocab at 0x13be29f28>,
#  '福建': <gensim.models.keyedvectors.Vocab at 0x13be29f60>,
#  '公司': <gensim.models.keyedvectors.Vocab at 0x13be29f98>,
#  '介紹': <gensim.models.keyedvectors.Vocab at 0x13be29fd0>,
#  '動工': <gensim.models.keyedvectors.Vocab at 0x13be2e048>,
#  '中鐵': <gensim.models.keyedvectors.Vocab at 0x13be2e080>,
#  '所處': <gensim.models.keyedvectors.Vocab at 0x13be2e0b8>,
#  '世界': <gensim.models.keyedvectors.Vocab at 0x13be2e0f0>,
#  '著名': <gensim.models.keyedvectors.Vocab at 0x13be2e128>,
#  '三大': <gensim.models.keyedvectors.Vocab at 0x13be2e160>,
#  '風暴': <gensim.models.keyedvectors.Vocab at 0x13be2e198>,
#  '海': <gensim.models.keyedvectors.Vocab at 0x13be2e1d0>,
#  '域': <gensim.models.keyedvectors.Vocab at 0x13be2e208>,
#  '之一': <gensim.models.keyedvectors.Vocab at 0x13be2e240>,
#  '海域': <gensim.models.keyedvectors.Vocab at 0x13be2e278>,
#  '環境': <gensim.models.keyedvectors.Vocab at 0x13be2e2b0>,
#  '複雜': <gensim.models.keyedvectors.Vocab at 0x13be2e2e8>,
#  '浪高': <gensim.models.keyedvectors.Vocab at 0x13be2e320>,
#  '波浪': <gensim.models.keyedvectors.Vocab at 0x13be2e358>,
#  '長江': <gensim.models.keyedvectors.Vocab at 0x13be2e390>,
#  '十倍': <gensim.models.keyedvectors.Vocab at 0x13be2e3c8>,
#  '以上': <gensim.models.keyedvectors.Vocab at 0x13be2e400>,
#  '大風': <gensim.models.keyedvectors.Vocab at 0x13be2e438>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x13be2e470>,
#  '惡劣': <gensim.models.keyedvectors.Vocab at 0x13be2e4a8>,
#  '有效': <gensim.models.keyedvectors.Vocab at 0x13be2e4e0>,
#  '作業': <gensim.models.keyedvectors.Vocab at 0x13be2e518>,
#  '時間': <gensim.models.keyedvectors.Vocab at 0x13be2e550>,
#  '施工': <gensim.models.keyedvectors.Vocab at 0x13be2e588>,
#  '難度': <gensim.models.keyedvectors.Vocab at 0x13be2e5c0>,
#  '極大': <gensim.models.keyedvectors.Vocab at 0x13be2e5f8>,
#  '被視': <gensim.models.keyedvectors.Vocab at 0x13be2e630>,
#  '禁區': <gensim.models.keyedvectors.Vocab at 0x13be2e668>,
#  '指出': <gensim.models.keyedvectors.Vocab at 0x13be2e6a0>,
#  '如此': <gensim.models.keyedvectors.Vocab at 0x13be2e6d8>,
#  '風浪': <gensim.models.keyedvectors.Vocab at 0x13be2e710>,
#  '湧': <gensim.models.keyedvectors.Vocab at 0x13be2e748>,
#  '興建': <gensim.models.keyedvectors.Vocab at 0x13be2e780>,
#  '建成': <gensim.models.keyedvectors.Vocab at 0x13be2e7b8>,
#  '必須': <gensim.models.keyedvectors.Vocab at 0x13be2e7f0>,
#  '滿足': <gensim.models.keyedvectors.Vocab at 0x13be2e828>,
#  '海上': <gensim.models.keyedvectors.Vocab at 0x13be2e860>,
#  '橋': <gensim.models.keyedvectors.Vocab at 0x13be2e898>,
#  '十級': <gensim.models.keyedvectors.Vocab at 0x13be2e8d0>,
#  '運營': <gensim.models.keyedvectors.Vocab at 0x13be2e908>,
#  '用量': <gensim.models.keyedvectors.Vocab at 0x13be2e940>,
#  '124': <gensim.models.keyedvectors.Vocab at 0x13be2e978>,
#  '萬噸': <gensim.models.keyedvectors.Vocab at 0x13be2e9b0>,
#  '土': <gensim.models.keyedvectors.Vocab at 0x13be2e9e8>,
#  ...}

# %%
df["content"][1]
# Out:
# '\n※發文無1~6小標格式或未依順序任意刪除者會被刪文\n\n1.媒體來源:聯合報\n※ 例如蘋果日報、自由時報（請參考版規下方的核准媒體名單）\n\n\n2.記者署名 記者周志豪\n※ 沒有在這打上記者署名的新聞會被水桶14天 編輯非記者\n※ 外電至少要有來源或編輯 如:法新社\n\n\n3.完整新聞標題:自排入不分區立委？ 李昭平：吳敦義從沒考慮放第一名\n※ 標題沒有完整寫出來 ---> 依照板規刪除文章\n\n\n4.完整新聞內文:\n國民黨主席吳敦義考慮是否自排入下屆國民黨不分區立委名單，但究竟要排在第一名或安\n全名單邊緣，各種聲音都有。中常委李昭平受訪時表示，吳上午在出席全國勞工後援會會\n議時，被出席代表問到相關問題，表示「從來沒有考慮放在第一名」。\n\n李昭平說，早上開勞工後援會，有人詢問吳敦義「是不是考慮放在國民黨不分區立委第一\n名」，吳回答「絕對沒有考慮過這件事情，沒有做這個考量過」。李昭平認為，吳事實上\n也不需要這樣考量，放在第一名就毫無意義。\n\n李昭平表示，黨內有這個聲音認為吳敦義如果能夠放在下屆不分區立委名單後段，在安全\n名單後面一點的話，對大家希望吳領頭羊往前衝，才是有意義的事情，放在第一名根本沒\n有意義，吳自己都說他不考慮。\n\n但吳敦義這樣的回應，是否代表吳敦義已經決定自放入名單，只是順序有別？李昭平說，\n吳有沒有考慮放入名單不知道，這是主席權力。\n※ 社論特稿都不能貼！違者刪除（政治類水桶3個月)，貼廣告也會被刪除喔！可詳看版規\n\n\n5.完整新聞連結 (或短網址):\nhttps://udn.com/news/story/7548/4095546?from=udn-ch1_breaknews-1-0-news\n※ 當新聞連結過長時，需提供短網址方便網友點擊\n\n\n6.備註:\n沒考慮放第一名\n\n可以放第二名\n※ 一個人一天只能張貼一則新聞，被刪或自刪也算額度內，超貼者水桶，請注意\n\n--\n'

# %%
from jieba.analyse import extract_tags
import numpy as np
article = df["content"][1]
tags = extract_tags(article,  None, withWeight=True)
total = np.zeros((100, ))
norm = 0.
for t, w in tags:
    if t in model.wv:
        total = total + w * model.wv[t]
        norm = norm + w
print("關鍵字平均:")
print(total / norm)
# Out:
# 關鍵字平均:
# [-4.79742888e-01  2.36786325e-01  8.09599040e-02  4.34400150e-01
#   3.33353653e-01  8.27744195e-01 -3.20211893e-01  4.83575120e-01
#   3.48531699e-01 -5.93076270e-02  4.71524051e-01 -2.01438921e-01
#   4.13241982e-04  1.67786782e-01 -1.12745089e-01  2.02327911e-01
#   4.89139244e-02  1.77091715e-01 -5.63143844e-02 -3.54481343e-01
#  -6.47201807e-01  1.12088357e-01 -4.17297767e-01  2.69628983e-01
#  -5.54118808e-01  2.75585945e-01  1.12485339e+00  6.80273445e-01
#   6.60469661e-02  2.14419132e-01  2.62256719e-01  1.01942833e-01
#   2.50403515e-01 -1.26583013e-01  3.88616896e-01 -9.44351133e-01
#  -4.42614497e-01  2.18587606e-01  1.84527203e-01  8.19293920e-01
#  -2.96563926e-01  4.04785103e-02 -2.27175515e-01  1.00144287e-01
#   4.18424294e-01 -2.15350270e-01 -1.80299596e-01  3.58639621e-01
#   3.97101195e-01 -3.68806833e-01  1.42567196e-01 -3.63189654e-01
#   1.83299598e-01  4.53190513e-01 -2.21062632e-01 -3.27171657e-01
#   1.83213358e-02  5.62653737e-01  4.57373377e-01 -4.99442719e-01
#  -4.71968938e-01 -7.83067269e-01 -6.13761971e-01  4.55618376e-01
#  -2.38647728e-01  8.84321459e-04 -4.02169051e-02  1.05174800e+00
#   5.13991003e-01  6.82855810e-01  4.39601820e-01 -4.76804639e-01
#  -3.07643066e-01 -7.40525127e-02 -2.90177581e-01  3.54587199e-01
#  -5.94149722e-01  1.62041324e-01  6.31367826e-01  2.29871829e-01
#   1.51142359e-01 -3.88165129e-01  2.98136816e-01 -1.35030155e-01
#   7.40488029e-01  4.16749872e-01  8.75000302e-01 -4.99040207e-02
#  -6.38998806e-02 -1.77736102e-01 -3.46767217e-01 -1.02276074e-01
#   3.90924013e-01 -9.06899517e-01 -9.88660303e-01  1.19518471e-01
#   1.32962629e-03  5.20576503e-03 -2.26648732e-01  1.23750404e+00]

# %%
def docvec(article):
    tags = extract_tags(article, None, withWeight=True)

    total = np.zeros((100, ))
    norm = 0.
    for t, w in tags:
        if t in model.wv:
            total = total + w * model.wv[t]
            norm = norm + w
    return total / norm
dv = df["content"].apply(docvec)
dv
# Out:
# 0        [-0.27588669888686423, 0.250240508450685, 0.17...
# 1        [-0.4797428884139356, 0.23678632523024, 0.0809...
# 2        [-0.6499560316523083, -0.1474620772953093, -0....
# 3        [-0.36989947869451645, 0.061021658377416944, 0...
# 4        [-0.2806017478921903, 0.4430333684815299, 0.27...
# 5        [-0.8555169516756038, -0.6351770840120166, -0....
# 6        [-0.3587018539669527, 0.28465583482223183, 0.0...
# 7        [-0.18492600047289529, 0.5699443722198133, 0.3...
# 8        [-0.5199477953249367, -0.2636182913201773, -0....
# 9        [-0.6286355996858595, 0.21772884244562468, -0....
# 10       [-0.795634331248724, -0.3197984423488545, -0.0...
# 11       [-0.48257926905815207, 0.05311248305343741, -0...
# 12       [-0.009547590221771093, 0.15836600704040668, 0...
# 13       [-0.2864929943547417, 0.10568246905171244, 0.1...
# 14       [-0.6812444415165582, 0.34123487664099494, -0....
# 15       [-1.0015686509336714, -0.06044216063174631, -0...
# 16       [-0.5229598464274368, -0.10264843982020017, -0...
# 17       [-0.7729344375149432, -0.2889492685160566, 0.0...
# 18       [-0.6157238351604787, 0.42594772549579535, -0....
# 19       [-0.46421819670565556, 0.033901412443814935, -...
# 20       [-0.19628881461611336, 0.12379274525036087, 0....
# 21       [-0.5670293010507225, -0.09848768882576675, 0....
# 22       [-0.6442233205617088, -0.17395373139219306, -0...
# 23       [-0.42637926220070477, 0.06037657108429752, 0....
# 24       [-0.42706448116401474, -0.16662972777241797, -...
# 25       [-0.0646251222685071, -0.08233457835838713, 0....
# 26       [-0.2901776040273098, -0.0019720846363172526, ...
# 27       [-0.5540727921826292, 0.1330447902843336, -0.1...
# 28       [-0.48054274963811294, -0.01785524897065946, 0...
# 29       [-0.8696906520192912, 0.7517723014681205, -0.4...
#                                ...
# 19970    [-0.7288682921180965, -0.06093579334100823, -0...
# 19971    [-0.28697670327335323, -0.005764894094122324, ...
# 19972    [-0.5995609793387775, -0.04139830263960785, -0...
# 19973    [-0.6715416727372082, 0.2508805936887553, -0.2...
# 19974    [-0.7230991298719409, -0.29481034356852615, -0...
# 19975    [-0.4768331629124208, 0.10384883482257987, -0....
# 19976    [-0.3690396694404213, 0.07507306364549182, 0.0...
# 19977    [-0.6140592130878136, 0.2163833612919181, -0.1...
# 19978    [-0.5151162179065746, -0.2980115623878241, 0.0...
# 19979    [-0.27366272039908507, 0.23206368976569353, 0....
# 19980    [-0.7054572290156007, -0.2809337322583771, -0....
# 19981    [-0.34128453260187336, 0.08270356325856221, 0....
# 19982    [-0.3053434959987271, 0.3436564354614014, 0.30...
# 19983    [-0.867800016925591, -0.3225523717850812, 0.29...
# 19984    [-0.646228949879089, 0.0879229977249896, -0.06...
# 19985    [-0.1990185408988716, -0.43176814826349397, 0....
# 19986    [-0.618418090735041, -0.5374088879986471, -0.2...
# 19987    [-0.1936464357809687, -0.1516581197597047, 0.1...
# 19988    [-0.7841375970541637, 0.28064872669978536, -0....
# 19989    [-0.30276240851972375, -0.2521479654130661, -0...
# 19990    [-0.6086381090065017, -0.1273070227491036, -0....
# 19991    [-0.5962586063069694, 0.0636898416988207, 0.06...
# 19992    [-0.6683641234594913, 0.008579307418043554, -0...
# 19993    [-0.30842392153708814, -0.10754162449052286, -...
# 19994    [-0.5677553054325334, 0.288271954870242, -0.01...
# 19995    [-0.6445940381587103, 0.1087069737917049, -0.1...
# 19996    [-0.4990012460547522, -0.2676292471564199, -0....
# 19997    [-0.7090512688532697, 0.6248341447780332, -0.2...
# 19998    [-0.7104791264830114, -0.479006921542836, -0.2...
# 19999    [-0.2978939551886796, 0.16743332635879896, 0.1...
# Name: content, Length: 20000, dtype: object

# %%
# 準備寫入我們的向量
f = open('article.txt' ,'w')
f.write('{} {}\n'.format(len(dv), 100))
for i, v in enumerate(dv):
    s = ' '.join(map(str, list(v)))
    f.write('{} {}\n'.format(i, s))
f.close()

# %%
import gensim
d2v = gensim.models.KeyedVectors.load_word2vec_format('./article.txt', binary=False)

# %%
i = input("選擇一篇文章:")
print("原文標題:", df.iloc[int(i)]["title"])
print("原文內容:", df.iloc[int(i)]["content"])

for si, sv in d2v.most_similar(i, topn=2):
    print("*" * 50)
    print("相似度:", sv)
    print("推薦標題:", df.iloc[int(si)]["title"])
    print("推薦內容:", df.iloc[int(si)]["content"])
# Out:
# 選擇一篇文章:1
# 原文標題: 自排入不分區立委？ 李昭平：吳敦義從沒
# 原文內容:
# ※發文無1~6小標格式或未依順序任意刪除者會被刪文
#
# 1.媒體來源:聯合報
# ※ 例如蘋果日報、自由時報（請參考版規下方的核准媒體名單）
#
#
# 2.記者署名 記者周志豪
# ※ 沒有在這打上記者署名的新聞會被水桶14天 編輯非記者
# ※ 外電至少要有來源或編輯 如:法新社
#
#
# 3.完整新聞標題:自排入不分區立委？ 李昭平：吳敦義從沒考慮放第一名
# ※ 標題沒有完整寫出來 ---> 依照板規刪除文章
#
#
# 4.完整新聞內文:
# 國民黨主席吳敦義考慮是否自排入下屆國民黨不分區立委名單，但究竟要排在第一名或安
# 全名單邊緣，各種聲音都有。中常委李昭平受訪時表示，吳上午在出席全國勞工後援會會
# 議時，被出席代表問到相關問題，表示「從來沒有考慮放在第一名」。
#
# 李昭平說，早上開勞工後援會，有人詢問吳敦義「是不是考慮放在國民黨不分區立委第一
# 名」，吳回答「絕對沒有考慮過這件事情，沒有做這個考量過」。李昭平認為，吳事實上
# 也不需要這樣考量，放在第一名就毫無意義。
#
# 李昭平表示，黨內有這個聲音認為吳敦義如果能夠放在下屆不分區立委名單後段，在安全
# 名單後面一點的話，對大家希望吳領頭羊往前衝，才是有意義的事情，放在第一名根本沒
# 有意義，吳自己都說他不考慮。
#
# 但吳敦義這樣的回應，是否代表吳敦義已經決定自放入名單，只是順序有別？李昭平說，
# 吳有沒有考慮放入名單不知道，這是主席權力。
# ※ 社論特稿都不能貼！違者刪除（政治類水桶3個月)，貼廣告也會被刪除喔！可詳看版規
#
#
# 5.完整新聞連結 (或短網址):
# https://udn.com/news/story/7548/4095546?from=udn-ch1_breaknews-1-0-news
# ※ 當新聞連結過長時，需提供短網址方便網友點擊
#
#
# 6.備註:
# 沒考慮放第一名
#
# 可以放第二名
# ※ 一個人一天只能張貼一則新聞，被刪或自刪也算額度內，超貼者水桶，請注意
#
# --
#
# **************************************************
# 相似度: 0.9842381477355957
# 推薦標題: 恐被下逐客令 他批國民黨處處羞辱郭董
# 推薦內容:
#
# 1.媒體來源:
# ※ 例如蘋果日報、自由時報（請參考版規下方的核准媒體名單）
# 自由
#
# 2.記者署名
# ※ 沒有在這打上記者署名的新聞會被版主刪除喔
# 〔記者林南谷／台北報導〕
#
# 3.完整新聞標題:
# ※ 標題沒有完整寫出來 ---> 依照板規刪除文章
# 恐被下逐客令 他批國民黨處處羞辱郭董
#
# 4.完整新聞內文:
# ※ 社論特稿都不能貼！違者刪除（政治類水桶3個月)，貼廣告也會被刪除喔！
#
# 國民黨總統初選激烈，倘若一掀鍋蓋，恐將引爆一顆超級不定時炸彈，有名嘴更爆國民黨
# 正配合「義和  」處處羞辱前鴻海董事長郭台銘。
# 正配合「義和  」處處羞辱前鴻海董事長郭台銘。
#
# 外界關注郭台銘會不會遭國民黨「開除黨籍」？電視評論員、名嘴黃創夏認為，吳敦義只
# 有收回「榮譽狀」，才有可能開除郭董黨籍，「既然如此，郭台銘如果『獨立參選』，也
# 就天經地義了。」
#
# 黃創夏還說，郭董因為被打壓，恐怕已經「失去理智」，「他現在就該下決心獨立參選，
# 而且並沒有脫黨問題」，黃創夏表示，郭董只是國民黨「榮譽黨員」，現在國民黨配合「
# 義和  」處處羞辱他，「既然郭董被剝奪榮譽，就是被下了逐客令」，他認為，郭董早該
# 拂袖而去。
#
#
# 5.完整新聞連結 (或短網址):
# ※ 當新聞連結過長時，需提供短網址方便網友點擊
#
# https://tinyurl.com/y5hnodfo
# 6.備註:
# ※ 一個人一天只能張貼一則新聞，被刪或自刪也算額度內，超貼者水桶，請注意
#
# 心得：對國民黨仁至義盡了脫黨拼到最後吧我們支持你
# -----
# Sent from JPTT on my iPhone
#
# --
# ※ 編輯: ul44ew (114.136.255.120 臺灣), 07/13/2019 15:40:49
#
# **************************************************
# 相似度: 0.9813991785049438
# 推薦標題: 吳郭會不了！ 郭陣營：9/17前都沒時間
# 推薦內容:
# ※發文無1~6小標格式或未依順序任意刪除者會被刪文
#
# 1.媒體來源:
# ※ 例如蘋果日報、自由時報（請參考版規下方的核准媒體名單）
# 自由時報
#
# 2.記者署名
# ※ 沒有在這打上記者署名的新聞會被水桶14天 編輯非記者
# ※ 外電至少要有來源或編輯 如:法新社
# 陳柔蓁
#
# 3.完整新聞標題:
# ※ 標題沒有完整寫出來 ---> 依照板規刪除文章
# 吳郭會不了！ 郭陣營：9/17前都沒時間
#
# 4.完整新聞內文:
# ※ 社論特稿都不能貼！違者刪除（政治類水桶3個月)，貼廣告也會被刪除喔！可詳看版規
# 〔記者陳柔蓁／台北報導〕外界好奇鴻海創辦人郭台銘與國民黨之間的互動，郭幕僚、永
# 齡基金會副執行長蔡沁瑜今（5）日指出，最後公民連署申請期限是9月17日，現在時間緊
# 迫，連找副手都來不及了，若要與黨主席吳敦義會面，9月17日前都沒時間。
#
# 蔡沁瑜說，郭台銘到現在都沒有跟她說選不選，郭有自己的想法跟盤算，若他下了決定，
# 是為了選贏不是選輸，整個組織都要動員起來，郭真的要參選，現在找副手都來不及了，
# 怎麼還有時間去搞形式？現在球是在國民黨那邊，就看他們怎麼決定。
#
# 蔡沁瑜透露，郭台銘與國民黨中央之間，有許多人穿梭溝通，至於見面的時間點，套前立
# 法院長王金平的話，就是「順應因緣」。然而，郭與國民黨之間，互信基礎沒那麼高，要
# 見也是私下見，否則萬一發生什麼事，媒體都在要怎麼處理？
#
# 先前傳出國民黨祭出立院龍頭與不分區立委第一名，來勸退郭台銘參與大選，後來國民黨
# 中央與郭台銘都否認此事，蔡沁瑜說，郭台銘聽到這件事，第一時間相當不悅，因他最不
# 齒這種交換、酬庸的行為發生，還說：「為什麼要拿這種事來講？」
#
#
#
# 5.完整新聞連結 (或短網址):
# ※ 當新聞連結過長時，需提供短網址方便網友點擊
# https://news.ltn.com.tw/news/politics/breakingnews/2906648
#
# 6.備註:
# ※ 一個人一天只能張貼一則新聞，被刪或自刪也算額度內，超貼者水桶，請注意
#
# --
#                                                           -----你所不知道的G軟
#
# --

# %%
i = input("選擇一篇文章:")
print("原文標題:", df.iloc[int(i)]["title"])
print("原文內容:", df.iloc[int(i)]["content"])
print("*" * 50)
for si, sv in d2v.most_similar(i):
    print("相似度:", sv)
    print("推薦標題:", df.iloc[int(si)]["title"])
    #print("推薦內容:", df.iloc[int(si)]["content"])
# Out:
# 選擇一篇文章:5
# 原文標題: 我不擔憂會相見恨晚
# 原文內容:
# 在第一眼 我就明白
# 肥宅有看到妹子ㄉ表情
# 就知道又要去警察局ㄌ
# 沒有女森要裡肥宅
# 該怎麼辦
# 有沒有八卦？
#
# --
#
# **************************************************
# 相似度: 0.9580479860305786
# 推薦標題: 香香的肥宅484很稀少
# 相似度: 0.9457191228866577
# 推薦標題: 發文不附圖到底都4什麼人?
# 相似度: 0.9426167011260986
# 推薦標題: 台哥大斷線？
# 相似度: 0.9404975175857544
# 推薦標題: 有沒有肥宅後悔成為肥宅的？
# 相似度: 0.9381184577941895
# 推薦標題: 有沒有超夢和夢幻的八卦
# 相似度: 0.9380680322647095
# 推薦標題: 有沒有忘了分類就被噓爆的八卦
# 相似度: 0.9373364448547363
# 推薦標題: 有學生在牢房裡不要出去怎麼辦？
# 相似度: 0.9364013075828552
# 推薦標題: 扯!!!!外送全部忙線
# 相似度: 0.9356891512870789
# 推薦標題: 八卦板一堆絕望文真的是絕望嗎？
# 相似度: 0.9353312849998474
# 推薦標題: 有沒有肥宅也想轉職當網紅啊？
