# %%
# %tensorflow_version 1.x

# %%
with open("倚天屠龍記.txt", "r", encoding="utf-8") as f:
    text = f.read()[:100000]

# %%
n = len(text)
print("倚天屠龍記共有 {} 中文字".format(n))
# Out:
# 倚天屠龍記共有 100000 中文字

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np
tok = Tokenizer(filters=None, char_level=True)
tok.fit_on_texts(text)
word_to_index = tok.word_index
word_to_index
# Out:
# {'，': 1,
#  '。': 2,
#  '一': 3,
#  '的': 4,
#  '不': 5,
#  '是': 6,
#  '“': 7,
#  '”': 8,
#  '道': 9,
#  '了': 10,
#  '：': 11,
#  '人': 12,
#  '這': 13,
#  '他': 14,
#  '來': 15,
#  '中': 16,
#  '大': 17,
#  '上': 18,
#  '下': 19,
#  '我': 20,
#  '張': 21,
#  '之': 22,
#  '手': 23,
#  '那': 24,
#  '？': 25,
#  '\u3000': 26,
#  '說': 27,
#  '山': 28,
#  '你': 29,
#  '得': 30,
#  '在': 31,
#  '見': 32,
#  '到': 33,
#  '出': 34,
#  '只': 35,
#  '聲': 36,
#  '有': 37,
#  '三': 38,
#  '便': 39,
#  '少': 40,
#  '心': 41,
#  '身': 42,
#  '當': 43,
#  '也': 44,
#  '無': 45,
#  '個': 46,
#  '翠': 47,
#  '子': 48,
#  '頭': 49,
#  '去': 50,
#  '自': 51,
#  '時': 52,
#  '著': 53,
#  '武': 54,
#  '師': 55,
#  '過': 56,
#  '天': 57,
#  '听': 58,
#  '么': 59,
#  '都': 60,
#  '然': 61,
#  '\n': 62,
#  '和': 63,
#  '何': 64,
#  '郭': 65,
#  '但': 66,
#  '林': 67,
#  '…': 68,
#  '襄': 69,
#  '兩': 70,
#  '們': 71,
#  '卻': 72,
#  '起': 73,
#  '知': 74,
#  '甚': 75,
#  '此': 76,
#  '又': 77,
#  '想': 78,
#  '鏢': 79,
#  '已': 80,
#  '俞': 81,
#  '功': 82,
#  '劍': 83,
#  '十': 84,
#  '老': 85,
#  '要': 86,
#  '寺': 87,
#  '而': 88,
#  '派': 89,
#  '門': 90,
#  '好': 91,
#  '如': 92,
#  '遠': 93,
#  '后': 94,
#  '名': 95,
#  '她': 96,
#  '向': 97,
#  '可': 98,
#  '年': 99,
#  '弟': 100,
#  '色': 101,
#  '岩': 102,
#  '气': 103,
#  '足': 104,
#  '事': 105,
#  '掌': 106,
#  '覺': 107,
#  '岱': 108,
#  '地': 109,
#  '僧': 110,
#  '將': 111,
#  '能': 112,
#  '刀': 113,
#  '笑': 114,
#  '眼': 115,
#  '相': 116,
#  '力': 117,
#  '對': 118,
#  '小': 119,
#  '招': 120,
#  '沒': 121,
#  '、': 122,
#  '女': 123,
#  '船': 124,
#  '里': 125,
#  '前': 126,
#  '話': 127,
#  '口': 128,
#  '寶': 129,
#  '二': 130,
#  '走': 131,
#  '錦': 132,
#  '俠': 133,
#  '動': 134,
#  '叫': 135,
#  '跟': 136,
#  '！': 137,
#  '步': 138,
#  '間': 139,
#  '龍': 140,
#  '多': 141,
#  '位': 142,
#  '法': 143,
#  '白': 144,
#  '方': 145,
#  '素': 146,
#  '為': 147,
#  '行': 148,
#  '面': 149,
#  '從': 150,
#  '還': 151,
#  '殷': 152,
#  '處': 153,
#  '高': 154,
#  '神': 155,
#  '左': 156,
#  '輕': 157,
#  '再': 158,
#  '己': 159,
#  '問': 160,
#  '生': 161,
#  '于': 162,
#  '住': 163,
#  '雙': 164,
#  '長': 165,
#  '所': 166,
#  '字': 167,
#  '竟': 168,
#  '若': 169,
#  '真': 170,
#  '正': 171,
#  '會': 172,
#  '臉': 173,
#  '四': 174,
#  '日': 175,
#  '重': 176,
#  '意': 177,
#  '者': 178,
#  '教': 179,
#  '以': 180,
#  '點': 181,
#  '江': 182,
#  '几': 183,
#  '惊': 184,
#  '回': 185,
#  '開': 186,
#  '數': 187,
#  '鐵': 188,
#  '傷': 189,
#  '看': 190,
#  '雖': 191,
#  '指': 192,
#  '眾': 193,
#  '瞧': 194,
#  '哥': 195,
#  '般': 196,
#  '給': 197,
#  '局': 198,
#  '打': 199,
#  '微': 200,
#  '姑': 201,
#  '半': 202,
#  '發': 203,
#  '右': 204,
#  '金': 205,
#  '似': 206,
#  '外': 207,
#  '尚': 208,
#  '娘': 209,
#  '七': 210,
#  '毒': 211,
#  '姓': 212,
#  '馬': 213,
#  '怎': 214,
#  '禪': 215,
#  '暗': 216,
#  '海': 217,
#  '轉': 218,
#  '父': 219,
#  '拳': 220,
#  '誰': 221,
#  '五': 222,
#  '命': 223,
#  '家': 224,
#  '原': 225,
#  '成': 226,
#  '風': 227,
#  '君': 228,
#  '才': 229,
#  '分': 230,
#  '水': 231,
#  '奇': 232,
#  '使': 233,
#  '響': 234,
#  '等': 235,
#  '非': 236,
#  '常': 237,
#  '擊': 238,
#  '啊': 239,
#  '喝': 240,
#  '望': 241,
#  '經': 242,
#  '主': 243,
#  '琴': 244,
#  '其': 245,
#  '未': 246,
#  '本': 247,
#  '快': 248,
#  '請': 249,
#  '進': 250,
#  '難': 251,
#  '哪': 252,
#  '堂': 253,
#  '連': 254,
#  '余': 255,
#  '客': 256,
#  '忽': 257,
#  '內': 258,
#  '伸': 259,
#  '急': 260,
#  '首': 261,
#  '實': 262,
#  '音': 263,
#  '定': 264,
#  '送': 265,
#  '言': 266,
#  '极': 267,
#  '圓': 268,
#  '冷': 269,
#  '光': 270,
#  '同': 271,
#  '倒': 272,
#  '罷': 273,
#  '路': 274,
#  '明': 275,
#  '學': 276,
#  '儿': 277,
#  '受': 278,
#  '西': 279,
#  '句': 280,
#  '丈': 281,
#  '湖': 282,
#  '死': 283,
#  '青': 284,
#  '沉': 285,
#  '夫': 286,
#  '‘': 287,
#  '性': 288,
#  '敵': 289,
#  '由': 290,
#  '就': 291,
#  '些': 292,
#  '必': 293,
#  '躍': 294,
#  '斷': 295,
#  '黑': 296,
#  '’': 297,
#  '用': 298,
#  '直': 299,
#  '漢': 300,
#  '接': 301,
#  '全': 302,
#  '入': 303,
#  '旁': 304,
#  '火': 305,
#  '即': 306,
#  '今': 307,
#  '總': 308,
#  '物': 309,
#  '更': 310,
#  '六': 311,
#  '敢': 312,
#  '屠': 313,
#  '花': 314,
#  '黃': 315,
#  '怒': 316,
#  '落': 317,
#  '丰': 318,
#  '把': 319,
#  '滿': 320,
#  '腳': 321,
#  '書': 322,
#  '呼': 323,
#  '縱': 324,
#  '傳': 325,
#  '怕': 326,
#  '往': 327,
#  '兄': 328,
#  '臂': 329,
#  '情': 330,
#  '放': 331,
#  '東': 332,
#  '越': 333,
#  '兵': 334,
#  '八': 335,
#  '千': 336,
#  '惡': 337,
#  '殺': 338,
#  '清': 339,
#  '作': 340,
#  '樣': 341,
#  '勢': 342,
#  '干': 343,
#  '救': 344,
#  '別': 345,
#  '并': 346,
#  '答': 347,
#  '赶': 348,
#  '邊': 349,
#  '猛': 350,
#  '圣': 351,
#  '苦': 352,
#  '深': 353,
#  '各': 354,
#  '留': 355,
#  '怪': 356,
#  '突': 357,
#  '交': 358,
#  '先': 359,
#  '幫': 360,
#  '奔': 361,
#  '待': 362,
#  '勁': 363,
#  '解': 364,
#  '昆': 365,
#  '侖': 366,
#  '衣': 367,
#  '比': 368,
#  '顯': 369,
#  '平': 370,
#  '既': 371,
#  '空': 372,
#  '鹽': 373,
#  '禮': 374,
#  '錯': 375,
#  '站': 376,
#  '巨': 377,
#  '立': 378,
#  '搖': 379,
#  '背': 380,
#  '鷹': 381,
#  '終': 382,
#  '羅': 383,
#  '追': 384,
#  '提': 385,
#  '登': 386,
#  '早': 387,
#  '臨': 388,
#  '爹': 389,
#  '理': 390,
#  '石': 391,
#  '座': 392,
#  '亂': 393,
#  '帶': 394,
#  '近': 395,
#  '莫': 396,
#  '橫': 397,
#  '刃': 398,
#  '害': 399,
#  '袍': 400,
#  '安': 401,
#  '沙': 402,
#  '百': 403,
#  '漸': 404,
#  '划': 405,
#  '宋': 406,
#  '居': 407,
#  '短': 408,
#  '底': 409,
#  '第': 410,
#  '咱': 411,
#  '舟': 412,
#  '低': 413,
#  '須': 414,
#  '反': 415,
#  '剛': 416,
#  '推': 417,
#  '絕': 418,
#  '九': 419,
#  '盡': 420,
#  '至': 421,
#  '隨': 422,
#  '搶': 423,
#  '令': 424,
#  '達': 425,
#  '取': 426,
#  '筆': 427,
#  '念': 428,
#  '楊': 429,
#  '精': 430,
#  '抓': 431,
#  '尊': 432,
#  '慢': 433,
#  '齊': 434,
#  '斗': 435,
#  '士': 436,
#  '緩': 437,
#  '單': 438,
#  '強': 439,
#  '乎': 440,
#  '變': 441,
#  '媽': 442,
#  '异': 443,
#  '閃': 444,
#  '及': 445,
#  '啦': 446,
#  '決': 447,
#  '樹': 448,
#  '通': 449,
#  '万': 450,
#  '應': 451,
#  '喜': 452,
#  '加': 453,
#  '片': 454,
#  '藥': 455,
#  '坐': 456,
#  '骨': 457,
#  '陽': 458,
#  '艙': 459,
#  '与': 460,
#  '久': 461,
#  '挑': 462,
#  '算': 463,
#  '血': 464,
#  '亭': 465,
#  '寫': 466,
#  '隱': 467,
#  '桶': 468,
#  '領': 469,
#  '因': 470,
#  '目': 471,
#  '鯨': 472,
#  '南': 473,
#  '豈': 474,
#  '吃': 475,
#  '合': 476,
#  '流': 477,
#  '揮': 478,
#  '緊': 479,
#  '月': 480,
#  '號': 481,
#  '飛': 482,
#  '刻': 483,
#  '條': 484,
#  '尋': 485,
#  '仍': 486,
#  '鳴': 487,
#  '摩': 488,
#  '肩': 489,
#  '狠': 490,
#  '親': 491,
#  '慧': 492,
#  '晚': 493,
#  '鵬': 494,
#  '游': 495,
#  '折': 496,
#  '疑': 497,
#  '識': 498,
#  '忙': 499,
#  '厲': 500,
#  '揚': 501,
#  '祝': 502,
#  '衛': 503,
#  '世': 504,
#  '容': 505,
#  '离': 506,
#  '屋': 507,
#  '威': 508,
#  '翻': 509,
#  '震': 510,
#  '斜': 511,
#  '硬': 512,
#  '器': 513,
#  '紅': 514,
#  '夜': 515,
#  '歲': 516,
#  '思': 517,
#  '牆': 518,
#  '找': 519,
#  '拿': 520,
#  '男': 521,
#  '鉤': 522,
#  '業': 523,
#  '橋': 524,
#  '壇': 525,
#  '語': 526,
#  '徒': 527,
#  '息': 528,
#  '遍': 529,
#  '細': 530,
#  '乃': 531,
#  '則': 532,
#  '友': 533,
#  '陣': 534,
#  '料': 535,
#  '服': 536,
#  '廟': 537,
#  '收': 538,
#  '均': 539,
#  '胸': 540,
#  '呆': 541,
#  '棋': 542,
#  '車': 543,
#  '潘': 544,
#  '護': 545,
#  '古': 546,
#  '做': 547,
#  '順': 548,
#  '許': 549,
#  '最': 550,
#  '頂': 551,
#  '妙': 552,
#  '稱': 553,
#  '施': 554,
#  '乘': 555,
#  '盤': 556,
#  '很': 557,
#  '耕': 558,
#  '穿': 559,
#  '影': 560,
#  '文': 561,
#  '停': 562,
#  '果': 563,
#  '感': 564,
#  '除': 565,
#  '柄': 566,
#  '關': 567,
#  '擔': 568,
#  '攻': 569,
#  '公': 570,
#  '番': 571,
#  '退': 572,
#  '袖': 573,
#  '彈': 574,
#  '腰': 575,
#  '眉': 576,
#  '倘': 577,
#  '杖': 578,
#  '貴': 579,
#  '信': 580,
#  '視': 581,
#  '胜': 582,
#  '北': 583,
#  '展': 584,
#  '瘦': 585,
#  '端': 586,
#  '頓': 587,
#  '朋': 588,
#  '角': 589,
#  '被': 590,
#  '休': 591,
#  '舉': 592,
#  '尖': 593,
#  '欲': 594,
#  '抱': 595,
#  '仇': 596,
#  '形': 597,
#  '另': 598,
#  '云': 599,
#  '藏': 600,
#  '鏈': 601,
#  '認': 602,
#  '觀': 603,
#  '呢': 604,
#  '截': 605,
#  '讓': 606,
#  '忍': 607,
#  '根': 608,
#  '擋': 609,
#  '禁': 610,
#  '凶': 611,
#  '偷': 612,
#  '畫': 613,
#  '輩': 614,
#  '梨': 615,
#  '照': 616,
#  '貌': 617,
#  '愛': 618,
#  '驢': 619,
#  '頗': 620,
#  '托': 621,
#  '練': 622,
#  '免': 623,
#  '勞': 624,
#  '報': 625,
#  '凝': 626,
#  '且': 627,
#  '歎': 628,
#  '雨': 629,
#  '英': 630,
#  '計': 631,
#  '避': 632,
#  '次': 633,
#  '破': 634,
#  '王': 635,
#  '裝': 636,
#  '否': 637,
#  '仰': 638,
#  '脫': 639,
#  '沖': 640,
#  '蒙': 641,
#  '化': 642,
#  '松': 643,
#  '毫': 644,
#  '壽': 645,
#  '曲': 646,
#  '廳': 647,
#  '德': 648,
#  '帆': 649,
#  '吟': 650,
#  '太': 651,
#  '示': 652,
#  '刺': 653,
#  '跳': 654,
#  '厚': 655,
#  '撞': 656,
#  '島': 657,
#  '耳': 658,
#  '域': 659,
#  '聞': 660,
#  '拍': 661,
#  '逼': 662,
#  '嘿': 663,
#  '丹': 664,
#  '陀': 665,
#  '銀': 666,
#  '默': 667,
#  '模': 668,
#  '虎': 669,
#  '踏': 670,
#  '疾': 671,
#  '奪': 672,
#  '腿': 673,
#  '該': 674,
#  '場': 675,
#  '痛': 676,
#  '穴': 677,
#  '嗎': 678,
#  '結': 679,
#  '架': 680,
#  '喀': 681,
#  '肉': 682,
#  '梟': 683,
#  '史': 684,
#  '換': 685,
#  '台': 686,
#  '工': 687,
#  '馳': 688,
#  '記': 689,
#  '攔': 690,
#  '适': 691,
#  '股': 692,
#  '運': 693,
#  '現': 694,
#  '側': 695,
#  '晃': 696,
#  '歷': 697,
#  '依': 698,
#  '腹': 699,
#  '約': 700,
#  '睡': 701,
#  '狂': 702,
#  '熱': 703,
#  '止': 704,
#  '弦': 705,
#  '借': 706,
#  '岸': 707,
#  '府': 708,
#  '紀': 709,
#  '淡': 710,
#  '拉': 711,
#  '獨': 712,
#  '規': 713,
#  '索': 714,
#  '官': 715,
#  '始': 716,
#  '佛': 717,
#  '量': 718,
#  '圈': 719,
#  '管': 720,
#  '鞘': 721,
#  '謝': 722,
#  '按': 723,
#  '悄': 724,
#  '藝': 725,
#  '持': 726,
#  '閣': 727,
#  '險': 728,
#  '較': 729,
#  '星': 730,
#  '制': 731,
#  '跌': 732,
#  '波': 733,
#  '砰': 734,
#  '辣': 735,
#  '扑': 736,
#  '伏': 737,
#  '元': 738,
#  '射': 739,
#  '差': 740,
#  '論': 741,
#  '露': 742,
#  '曾': 743,
#  '件': 744,
#  '飄': 745,
#  '喪': 746,
#  '哼': 747,
#  '滾': 748,
#  '鋒': 749,
#  '怀': 750,
#  '顧': 751,
#  '涌': 752,
#  '巧': 753,
#  '初': 754,
#  '祖': 755,
#  '絲': 756,
#  '谷': 757,
#  '冒': 758,
#  '套': 759,
#  '致': 760,
#  '像': 761,
#  '閉': 762,
#  '皆': 763,
#  '溪': 764,
#  '智': 765,
#  '保': 766,
#  '爺': 767,
#  '枚': 768,
#  '土': 769,
#  '机': 770,
#  '騎': 771,
#  '姊': 772,
#  '任': 773,
#  '華': 774,
#  '爭': 775,
#  '際': 776,
#  '偏': 777,
#  '肯': 778,
#  '究': 779,
#  '怔': 780,
#  '失': 781,
#  '劇': 782,
#  '易': 783,
#  '鬧': 784,
#  '抵': 785,
#  '倚': 786,
#  '体': 787,
#  '哈': 788,
#  '混': 789,
#  '抬': 790,
#  '授': 791,
#  '每': 792,
#  '嗯': 793,
#  '引': 794,
#  '燭': 795,
#  '旗': 796,
#  '賊': 797,
#  '《': 798,
#  '》': 799,
#  '詞': 800,
#  '痴': 801,
#  '共': 802,
#  '求': 803,
#  '故': 804,
#  '徑': 805,
#  '粗': 806,
#  '欺': 807,
#  '善': 808,
#  '闖': 809,
#  '朗': 810,
#  '牢': 811,
#  '腕': 812,
#  '敗': 813,
#  '燈': 814,
#  '瓜': 815,
#  '燒': 816,
#  '部': 817,
#  '挺': 818,
#  '興': 819,
#  '寂': 820,
#  '膝': 821,
#  '愈': 822,
#  '活': 823,
#  '裂': 824,
#  '虛': 825,
#  '逃': 826,
#  '界': 827,
#  '亮': 828,
#  '潮': 829,
#  '寒': 830,
#  '節': 831,
#  '群': 832,
#  '拔': 833,
#  '衫': 834,
#  '邪': 835,
#  '酒': 836,
#  '修': 837,
#  '蹤': 838,
#  '距': 839,
#  '試': 840,
#  '井': 841,
#  '悟': 842,
#  '景': 843,
#  '垂': 844,
#  '毛': 845,
#  '驀': 846,
#  '睜': 847,
#  '雅': 848,
#  '凌': 849,
#  '恭': 850,
#  '嗤': 851,
#  '訣': 852,
#  '團': 853,
#  '諸': 854,
#  '互': 855,
#  '敬': 856,
#  '楞': 857,
#  '舍': 858,
#  '浪': 859,
#  '尺': 860,
#  '隔': 861,
#  '兀': 862,
#  '碎': 863,
#  '懂': 864,
#  '盜': 865,
#  '板': 866,
#  '慘': 867,
#  '錢': 868,
#  '助': 869,
#  '艘': 870,
#  '錨': 871,
#  '梅': 872,
#  '蕩': 873,
#  '俗': 874,
#  '切': 875,
#  '寬': 876,
#  '布': 877,
#  '木': 878,
#  '婦': 879,
#  '斤': 880,
#  '惱': 881,
#  '探': 882,
#  '掃': 883,
#  '敝': 884,
#  '赴': 885,
#  '茶': 886,
#  '嘴': 887,
#  '擒': 888,
#  '拋': 889,
#  '激': 890,
#  '溜': 891,
#  '擲': 892,
#  '顫': 893,
#  '嚴': 894,
#  '拚': 895,
#  '遇': 896,
#  '夠': 897,
#  '歇': 898,
#  '醒': 899,
#  '鼓': 900,
#  '喇': 901,
#  '頰': 902,
#  '插': 903,
#  '穩': 904,
#  '怨': 905,
#  '恩': 906,
#  '誤': 907,
#  '爐': 908,
#  '痣': 909,
#  '靜': 910,
#  '憂': 911,
#  '握': 912,
#  '啷': 913,
#  '伽': 914,
#  '寸': 915,
#  '佩': 916,
#  '守': 917,
#  '奉': 918,
#  '摔': 919,
#  '猶': 920,
#  '調': 921,
#  '包': 922,
#  '遲': 923,
#  '扯': 924,
#  '吸': 925,
#  '纏': 926,
#  '式': 927,
#  '術': 928,
#  '盛': 929,
#  '完': 930,
#  '凡': 931,
#  '晌': 932,
#  '格': 933,
#  '草': 934,
#  '查': 935,
#  '雄': 936,
#  '戰': 937,
#  '鳥': 938,
#  '危': 939,
#  '密': 940,
#  '韻': 941,
#  '蹄': 942,
#  '瞪': 943,
#  '駕': 944,
#  '摸': 945,
#  '民': 946,
#  '靠': 947,
#  '塘': 948,
#  '房': 949,
#  '楚': 950,
#  '怦': 951,
#  '春': 952,
#  '雪': 953,
#  '靈': 954,
#  '良': 955,
#  '襲': 956,
#  '程': 957,
#  '俯': 958,
#  '院': 959,
#  '充': 960,
#  '訊': 961,
#  '怖': 962,
#  '戒': 963,
#  '撒': 964,
#  '累': 965,
#  '迅': 966,
#  '陷': 967,
#  '克': 968,
#  '散': 969,
#  '籠': 970,
#  '告': 971,
#  '胡': 972,
#  '卷': 973,
#  '略': 974,
#  '代': 975,
#  '輸': 976,
#  '狗': 977,
#  '講': 978,
#  '弱': 979,
#  '拆': 980,
#  '泥': 981,
#  '戶': 982,
#  '周': 983,
#  '扇': 984,
#  '辰': 985,
#  '飯': 986,
#  '忘': 987,
#  '瀟': 988,
#  '紙': 989,
#  '負': 990,
#  '郁': 991,
#  '途': 992,
#  '測': 993,
#  '支': 994,
#  '義': 995,
#  '柱': 996,
#  '尸': 997,
#  '遭': 998,
#  '帖': 999,
#  '迎': 1000,
#  ...}

# %%
index_to_word = {v:k for k, v in word_to_index.items()}
index_to_word
# Out:
# {1: '，',
#  2: '。',
#  3: '一',
#  4: '的',
#  5: '不',
#  6: '是',
#  7: '“',
#  8: '”',
#  9: '道',
#  10: '了',
#  11: '：',
#  12: '人',
#  13: '這',
#  14: '他',
#  15: '來',
#  16: '中',
#  17: '大',
#  18: '上',
#  19: '下',
#  20: '我',
#  21: '張',
#  22: '之',
#  23: '手',
#  24: '那',
#  25: '？',
#  26: '\u3000',
#  27: '說',
#  28: '山',
#  29: '你',
#  30: '得',
#  31: '在',
#  32: '見',
#  33: '到',
#  34: '出',
#  35: '只',
#  36: '聲',
#  37: '有',
#  38: '三',
#  39: '便',
#  40: '少',
#  41: '心',
#  42: '身',
#  43: '當',
#  44: '也',
#  45: '無',
#  46: '個',
#  47: '翠',
#  48: '子',
#  49: '頭',
#  50: '去',
#  51: '自',
#  52: '時',
#  53: '著',
#  54: '武',
#  55: '師',
#  56: '過',
#  57: '天',
#  58: '听',
#  59: '么',
#  60: '都',
#  61: '然',
#  62: '\n',
#  63: '和',
#  64: '何',
#  65: '郭',
#  66: '但',
#  67: '林',
#  68: '…',
#  69: '襄',
#  70: '兩',
#  71: '們',
#  72: '卻',
#  73: '起',
#  74: '知',
#  75: '甚',
#  76: '此',
#  77: '又',
#  78: '想',
#  79: '鏢',
#  80: '已',
#  81: '俞',
#  82: '功',
#  83: '劍',
#  84: '十',
#  85: '老',
#  86: '要',
#  87: '寺',
#  88: '而',
#  89: '派',
#  90: '門',
#  91: '好',
#  92: '如',
#  93: '遠',
#  94: '后',
#  95: '名',
#  96: '她',
#  97: '向',
#  98: '可',
#  99: '年',
#  100: '弟',
#  101: '色',
#  102: '岩',
#  103: '气',
#  104: '足',
#  105: '事',
#  106: '掌',
#  107: '覺',
#  108: '岱',
#  109: '地',
#  110: '僧',
#  111: '將',
#  112: '能',
#  113: '刀',
#  114: '笑',
#  115: '眼',
#  116: '相',
#  117: '力',
#  118: '對',
#  119: '小',
#  120: '招',
#  121: '沒',
#  122: '、',
#  123: '女',
#  124: '船',
#  125: '里',
#  126: '前',
#  127: '話',
#  128: '口',
#  129: '寶',
#  130: '二',
#  131: '走',
#  132: '錦',
#  133: '俠',
#  134: '動',
#  135: '叫',
#  136: '跟',
#  137: '！',
#  138: '步',
#  139: '間',
#  140: '龍',
#  141: '多',
#  142: '位',
#  143: '法',
#  144: '白',
#  145: '方',
#  146: '素',
#  147: '為',
#  148: '行',
#  149: '面',
#  150: '從',
#  151: '還',
#  152: '殷',
#  153: '處',
#  154: '高',
#  155: '神',
#  156: '左',
#  157: '輕',
#  158: '再',
#  159: '己',
#  160: '問',
#  161: '生',
#  162: '于',
#  163: '住',
#  164: '雙',
#  165: '長',
#  166: '所',
#  167: '字',
#  168: '竟',
#  169: '若',
#  170: '真',
#  171: '正',
#  172: '會',
#  173: '臉',
#  174: '四',
#  175: '日',
#  176: '重',
#  177: '意',
#  178: '者',
#  179: '教',
#  180: '以',
#  181: '點',
#  182: '江',
#  183: '几',
#  184: '惊',
#  185: '回',
#  186: '開',
#  187: '數',
#  188: '鐵',
#  189: '傷',
#  190: '看',
#  191: '雖',
#  192: '指',
#  193: '眾',
#  194: '瞧',
#  195: '哥',
#  196: '般',
#  197: '給',
#  198: '局',
#  199: '打',
#  200: '微',
#  201: '姑',
#  202: '半',
#  203: '發',
#  204: '右',
#  205: '金',
#  206: '似',
#  207: '外',
#  208: '尚',
#  209: '娘',
#  210: '七',
#  211: '毒',
#  212: '姓',
#  213: '馬',
#  214: '怎',
#  215: '禪',
#  216: '暗',
#  217: '海',
#  218: '轉',
#  219: '父',
#  220: '拳',
#  221: '誰',
#  222: '五',
#  223: '命',
#  224: '家',
#  225: '原',
#  226: '成',
#  227: '風',
#  228: '君',
#  229: '才',
#  230: '分',
#  231: '水',
#  232: '奇',
#  233: '使',
#  234: '響',
#  235: '等',
#  236: '非',
#  237: '常',
#  238: '擊',
#  239: '啊',
#  240: '喝',
#  241: '望',
#  242: '經',
#  243: '主',
#  244: '琴',
#  245: '其',
#  246: '未',
#  247: '本',
#  248: '快',
#  249: '請',
#  250: '進',
#  251: '難',
#  252: '哪',
#  253: '堂',
#  254: '連',
#  255: '余',
#  256: '客',
#  257: '忽',
#  258: '內',
#  259: '伸',
#  260: '急',
#  261: '首',
#  262: '實',
#  263: '音',
#  264: '定',
#  265: '送',
#  266: '言',
#  267: '极',
#  268: '圓',
#  269: '冷',
#  270: '光',
#  271: '同',
#  272: '倒',
#  273: '罷',
#  274: '路',
#  275: '明',
#  276: '學',
#  277: '儿',
#  278: '受',
#  279: '西',
#  280: '句',
#  281: '丈',
#  282: '湖',
#  283: '死',
#  284: '青',
#  285: '沉',
#  286: '夫',
#  287: '‘',
#  288: '性',
#  289: '敵',
#  290: '由',
#  291: '就',
#  292: '些',
#  293: '必',
#  294: '躍',
#  295: '斷',
#  296: '黑',
#  297: '’',
#  298: '用',
#  299: '直',
#  300: '漢',
#  301: '接',
#  302: '全',
#  303: '入',
#  304: '旁',
#  305: '火',
#  306: '即',
#  307: '今',
#  308: '總',
#  309: '物',
#  310: '更',
#  311: '六',
#  312: '敢',
#  313: '屠',
#  314: '花',
#  315: '黃',
#  316: '怒',
#  317: '落',
#  318: '丰',
#  319: '把',
#  320: '滿',
#  321: '腳',
#  322: '書',
#  323: '呼',
#  324: '縱',
#  325: '傳',
#  326: '怕',
#  327: '往',
#  328: '兄',
#  329: '臂',
#  330: '情',
#  331: '放',
#  332: '東',
#  333: '越',
#  334: '兵',
#  335: '八',
#  336: '千',
#  337: '惡',
#  338: '殺',
#  339: '清',
#  340: '作',
#  341: '樣',
#  342: '勢',
#  343: '干',
#  344: '救',
#  345: '別',
#  346: '并',
#  347: '答',
#  348: '赶',
#  349: '邊',
#  350: '猛',
#  351: '圣',
#  352: '苦',
#  353: '深',
#  354: '各',
#  355: '留',
#  356: '怪',
#  357: '突',
#  358: '交',
#  359: '先',
#  360: '幫',
#  361: '奔',
#  362: '待',
#  363: '勁',
#  364: '解',
#  365: '昆',
#  366: '侖',
#  367: '衣',
#  368: '比',
#  369: '顯',
#  370: '平',
#  371: '既',
#  372: '空',
#  373: '鹽',
#  374: '禮',
#  375: '錯',
#  376: '站',
#  377: '巨',
#  378: '立',
#  379: '搖',
#  380: '背',
#  381: '鷹',
#  382: '終',
#  383: '羅',
#  384: '追',
#  385: '提',
#  386: '登',
#  387: '早',
#  388: '臨',
#  389: '爹',
#  390: '理',
#  391: '石',
#  392: '座',
#  393: '亂',
#  394: '帶',
#  395: '近',
#  396: '莫',
#  397: '橫',
#  398: '刃',
#  399: '害',
#  400: '袍',
#  401: '安',
#  402: '沙',
#  403: '百',
#  404: '漸',
#  405: '划',
#  406: '宋',
#  407: '居',
#  408: '短',
#  409: '底',
#  410: '第',
#  411: '咱',
#  412: '舟',
#  413: '低',
#  414: '須',
#  415: '反',
#  416: '剛',
#  417: '推',
#  418: '絕',
#  419: '九',
#  420: '盡',
#  421: '至',
#  422: '隨',
#  423: '搶',
#  424: '令',
#  425: '達',
#  426: '取',
#  427: '筆',
#  428: '念',
#  429: '楊',
#  430: '精',
#  431: '抓',
#  432: '尊',
#  433: '慢',
#  434: '齊',
#  435: '斗',
#  436: '士',
#  437: '緩',
#  438: '單',
#  439: '強',
#  440: '乎',
#  441: '變',
#  442: '媽',
#  443: '异',
#  444: '閃',
#  445: '及',
#  446: '啦',
#  447: '決',
#  448: '樹',
#  449: '通',
#  450: '万',
#  451: '應',
#  452: '喜',
#  453: '加',
#  454: '片',
#  455: '藥',
#  456: '坐',
#  457: '骨',
#  458: '陽',
#  459: '艙',
#  460: '与',
#  461: '久',
#  462: '挑',
#  463: '算',
#  464: '血',
#  465: '亭',
#  466: '寫',
#  467: '隱',
#  468: '桶',
#  469: '領',
#  470: '因',
#  471: '目',
#  472: '鯨',
#  473: '南',
#  474: '豈',
#  475: '吃',
#  476: '合',
#  477: '流',
#  478: '揮',
#  479: '緊',
#  480: '月',
#  481: '號',
#  482: '飛',
#  483: '刻',
#  484: '條',
#  485: '尋',
#  486: '仍',
#  487: '鳴',
#  488: '摩',
#  489: '肩',
#  490: '狠',
#  491: '親',
#  492: '慧',
#  493: '晚',
#  494: '鵬',
#  495: '游',
#  496: '折',
#  497: '疑',
#  498: '識',
#  499: '忙',
#  500: '厲',
#  501: '揚',
#  502: '祝',
#  503: '衛',
#  504: '世',
#  505: '容',
#  506: '离',
#  507: '屋',
#  508: '威',
#  509: '翻',
#  510: '震',
#  511: '斜',
#  512: '硬',
#  513: '器',
#  514: '紅',
#  515: '夜',
#  516: '歲',
#  517: '思',
#  518: '牆',
#  519: '找',
#  520: '拿',
#  521: '男',
#  522: '鉤',
#  523: '業',
#  524: '橋',
#  525: '壇',
#  526: '語',
#  527: '徒',
#  528: '息',
#  529: '遍',
#  530: '細',
#  531: '乃',
#  532: '則',
#  533: '友',
#  534: '陣',
#  535: '料',
#  536: '服',
#  537: '廟',
#  538: '收',
#  539: '均',
#  540: '胸',
#  541: '呆',
#  542: '棋',
#  543: '車',
#  544: '潘',
#  545: '護',
#  546: '古',
#  547: '做',
#  548: '順',
#  549: '許',
#  550: '最',
#  551: '頂',
#  552: '妙',
#  553: '稱',
#  554: '施',
#  555: '乘',
#  556: '盤',
#  557: '很',
#  558: '耕',
#  559: '穿',
#  560: '影',
#  561: '文',
#  562: '停',
#  563: '果',
#  564: '感',
#  565: '除',
#  566: '柄',
#  567: '關',
#  568: '擔',
#  569: '攻',
#  570: '公',
#  571: '番',
#  572: '退',
#  573: '袖',
#  574: '彈',
#  575: '腰',
#  576: '眉',
#  577: '倘',
#  578: '杖',
#  579: '貴',
#  580: '信',
#  581: '視',
#  582: '胜',
#  583: '北',
#  584: '展',
#  585: '瘦',
#  586: '端',
#  587: '頓',
#  588: '朋',
#  589: '角',
#  590: '被',
#  591: '休',
#  592: '舉',
#  593: '尖',
#  594: '欲',
#  595: '抱',
#  596: '仇',
#  597: '形',
#  598: '另',
#  599: '云',
#  600: '藏',
#  601: '鏈',
#  602: '認',
#  603: '觀',
#  604: '呢',
#  605: '截',
#  606: '讓',
#  607: '忍',
#  608: '根',
#  609: '擋',
#  610: '禁',
#  611: '凶',
#  612: '偷',
#  613: '畫',
#  614: '輩',
#  615: '梨',
#  616: '照',
#  617: '貌',
#  618: '愛',
#  619: '驢',
#  620: '頗',
#  621: '托',
#  622: '練',
#  623: '免',
#  624: '勞',
#  625: '報',
#  626: '凝',
#  627: '且',
#  628: '歎',
#  629: '雨',
#  630: '英',
#  631: '計',
#  632: '避',
#  633: '次',
#  634: '破',
#  635: '王',
#  636: '裝',
#  637: '否',
#  638: '仰',
#  639: '脫',
#  640: '沖',
#  641: '蒙',
#  642: '化',
#  643: '松',
#  644: '毫',
#  645: '壽',
#  646: '曲',
#  647: '廳',
#  648: '德',
#  649: '帆',
#  650: '吟',
#  651: '太',
#  652: '示',
#  653: '刺',
#  654: '跳',
#  655: '厚',
#  656: '撞',
#  657: '島',
#  658: '耳',
#  659: '域',
#  660: '聞',
#  661: '拍',
#  662: '逼',
#  663: '嘿',
#  664: '丹',
#  665: '陀',
#  666: '銀',
#  667: '默',
#  668: '模',
#  669: '虎',
#  670: '踏',
#  671: '疾',
#  672: '奪',
#  673: '腿',
#  674: '該',
#  675: '場',
#  676: '痛',
#  677: '穴',
#  678: '嗎',
#  679: '結',
#  680: '架',
#  681: '喀',
#  682: '肉',
#  683: '梟',
#  684: '史',
#  685: '換',
#  686: '台',
#  687: '工',
#  688: '馳',
#  689: '記',
#  690: '攔',
#  691: '适',
#  692: '股',
#  693: '運',
#  694: '現',
#  695: '側',
#  696: '晃',
#  697: '歷',
#  698: '依',
#  699: '腹',
#  700: '約',
#  701: '睡',
#  702: '狂',
#  703: '熱',
#  704: '止',
#  705: '弦',
#  706: '借',
#  707: '岸',
#  708: '府',
#  709: '紀',
#  710: '淡',
#  711: '拉',
#  712: '獨',
#  713: '規',
#  714: '索',
#  715: '官',
#  716: '始',
#  717: '佛',
#  718: '量',
#  719: '圈',
#  720: '管',
#  721: '鞘',
#  722: '謝',
#  723: '按',
#  724: '悄',
#  725: '藝',
#  726: '持',
#  727: '閣',
#  728: '險',
#  729: '較',
#  730: '星',
#  731: '制',
#  732: '跌',
#  733: '波',
#  734: '砰',
#  735: '辣',
#  736: '扑',
#  737: '伏',
#  738: '元',
#  739: '射',
#  740: '差',
#  741: '論',
#  742: '露',
#  743: '曾',
#  744: '件',
#  745: '飄',
#  746: '喪',
#  747: '哼',
#  748: '滾',
#  749: '鋒',
#  750: '怀',
#  751: '顧',
#  752: '涌',
#  753: '巧',
#  754: '初',
#  755: '祖',
#  756: '絲',
#  757: '谷',
#  758: '冒',
#  759: '套',
#  760: '致',
#  761: '像',
#  762: '閉',
#  763: '皆',
#  764: '溪',
#  765: '智',
#  766: '保',
#  767: '爺',
#  768: '枚',
#  769: '土',
#  770: '机',
#  771: '騎',
#  772: '姊',
#  773: '任',
#  774: '華',
#  775: '爭',
#  776: '際',
#  777: '偏',
#  778: '肯',
#  779: '究',
#  780: '怔',
#  781: '失',
#  782: '劇',
#  783: '易',
#  784: '鬧',
#  785: '抵',
#  786: '倚',
#  787: '体',
#  788: '哈',
#  789: '混',
#  790: '抬',
#  791: '授',
#  792: '每',
#  793: '嗯',
#  794: '引',
#  795: '燭',
#  796: '旗',
#  797: '賊',
#  798: '《',
#  799: '》',
#  800: '詞',
#  801: '痴',
#  802: '共',
#  803: '求',
#  804: '故',
#  805: '徑',
#  806: '粗',
#  807: '欺',
#  808: '善',
#  809: '闖',
#  810: '朗',
#  811: '牢',
#  812: '腕',
#  813: '敗',
#  814: '燈',
#  815: '瓜',
#  816: '燒',
#  817: '部',
#  818: '挺',
#  819: '興',
#  820: '寂',
#  821: '膝',
#  822: '愈',
#  823: '活',
#  824: '裂',
#  825: '虛',
#  826: '逃',
#  827: '界',
#  828: '亮',
#  829: '潮',
#  830: '寒',
#  831: '節',
#  832: '群',
#  833: '拔',
#  834: '衫',
#  835: '邪',
#  836: '酒',
#  837: '修',
#  838: '蹤',
#  839: '距',
#  840: '試',
#  841: '井',
#  842: '悟',
#  843: '景',
#  844: '垂',
#  845: '毛',
#  846: '驀',
#  847: '睜',
#  848: '雅',
#  849: '凌',
#  850: '恭',
#  851: '嗤',
#  852: '訣',
#  853: '團',
#  854: '諸',
#  855: '互',
#  856: '敬',
#  857: '楞',
#  858: '舍',
#  859: '浪',
#  860: '尺',
#  861: '隔',
#  862: '兀',
#  863: '碎',
#  864: '懂',
#  865: '盜',
#  866: '板',
#  867: '慘',
#  868: '錢',
#  869: '助',
#  870: '艘',
#  871: '錨',
#  872: '梅',
#  873: '蕩',
#  874: '俗',
#  875: '切',
#  876: '寬',
#  877: '布',
#  878: '木',
#  879: '婦',
#  880: '斤',
#  881: '惱',
#  882: '探',
#  883: '掃',
#  884: '敝',
#  885: '赴',
#  886: '茶',
#  887: '嘴',
#  888: '擒',
#  889: '拋',
#  890: '激',
#  891: '溜',
#  892: '擲',
#  893: '顫',
#  894: '嚴',
#  895: '拚',
#  896: '遇',
#  897: '夠',
#  898: '歇',
#  899: '醒',
#  900: '鼓',
#  901: '喇',
#  902: '頰',
#  903: '插',
#  904: '穩',
#  905: '怨',
#  906: '恩',
#  907: '誤',
#  908: '爐',
#  909: '痣',
#  910: '靜',
#  911: '憂',
#  912: '握',
#  913: '啷',
#  914: '伽',
#  915: '寸',
#  916: '佩',
#  917: '守',
#  918: '奉',
#  919: '摔',
#  920: '猶',
#  921: '調',
#  922: '包',
#  923: '遲',
#  924: '扯',
#  925: '吸',
#  926: '纏',
#  927: '式',
#  928: '術',
#  929: '盛',
#  930: '完',
#  931: '凡',
#  932: '晌',
#  933: '格',
#  934: '草',
#  935: '查',
#  936: '雄',
#  937: '戰',
#  938: '鳥',
#  939: '危',
#  940: '密',
#  941: '韻',
#  942: '蹄',
#  943: '瞪',
#  944: '駕',
#  945: '摸',
#  946: '民',
#  947: '靠',
#  948: '塘',
#  949: '房',
#  950: '楚',
#  951: '怦',
#  952: '春',
#  953: '雪',
#  954: '靈',
#  955: '良',
#  956: '襲',
#  957: '程',
#  958: '俯',
#  959: '院',
#  960: '充',
#  961: '訊',
#  962: '怖',
#  963: '戒',
#  964: '撒',
#  965: '累',
#  966: '迅',
#  967: '陷',
#  968: '克',
#  969: '散',
#  970: '籠',
#  971: '告',
#  972: '胡',
#  973: '卷',
#  974: '略',
#  975: '代',
#  976: '輸',
#  977: '狗',
#  978: '講',
#  979: '弱',
#  980: '拆',
#  981: '泥',
#  982: '戶',
#  983: '周',
#  984: '扇',
#  985: '辰',
#  986: '飯',
#  987: '忘',
#  988: '瀟',
#  989: '紙',
#  990: '負',
#  991: '郁',
#  992: '途',
#  993: '測',
#  994: '支',
#  995: '義',
#  996: '柱',
#  997: '尸',
#  998: '遭',
#  999: '帖',
#  1000: '迎',
#  ...}

# %%
chars = [c for c in text if c in word_to_index]
charints = [word_to_index[c] for c in chars]
V = len(word_to_index)
print("包含了 {} 個獨一無二的字".format(V))
print("原文(10):", text[:10])
print("原文(10):", chars[:10])
print("轉換(10):", charints[:10])
# Out:
# 包含了 2620 個獨一無二的字
# 原文(10): “春游浩蕩，是年年寒
# 原文(10): ['“', '春', '游', '浩', '蕩', '，', '是', '年', '年', '寒']
# 轉換(10): [7, 952, 495, 1516, 873, 1, 6, 99, 99, 830]

# %%
def generate_data(corpus, window=10):
    times = len(corpus) // window
    result = []
    for i in range(times):
        start = i * window
        end = i * window + (window + 1)
        words = corpus[start:end]
        if len(words) == window + 1:
            x = words[:-1]
            y = words[1:]
            result.append((x, y))
    return result
g = generate_data(charints)
g

# %%
import random
def batch_data(corpus, batch=64, window=10):
    g = generate_data(corpus, window)
    random.shuffle(g)
    batchx = []
    batchy = []
    for x, y in g:
        batchx.append(np.array(x))
        batchy.append(np.array(y))
        if len(batchx) == batch:
            yield (np.array(batchx), np.array(batchy))
            batchx = []
            batchy = []
g = batch_data(charints)
for _ in range(2):
    print(g.__next__())

# %%
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Dense
EMBEDDING_DIM = 128
RNN_UNITS = 64
BATCH_SIZE = 64
SEQ_LENGTH = 256
# 使用 keras 建立一個非常簡單的 LSTM 模型
model = Sequential()
# 詞嵌入層
# 將每個索引數字對應到一個高維空間的向量
model.add(Embedding(input_dim=V+1, 
                    mask_zero=True,
                    output_dim=EMBEDDING_DIM, 
                    batch_input_shape=(BATCH_SIZE, SEQ_LENGTH)))

# LSTM 層
# 負責將序列數據依序讀入並做處理
model.add(LSTM(units=RNN_UNITS, 
               return_sequences=True))

# 全連接層
# 負責 model 每個中文字出現的可能性
model.add(Dense(V+1, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (64, 256, 128)            335360
# _________________________________________________________________
# lstm_2 (LSTM)                (64, 256, 64)             49408
# _________________________________________________________________
# dense_2 (Dense)              (64, 256, 2621)           170365
# =================================================================
# Total params: 555,133
# Trainable params: 555,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam")

# %%
from keras.utils.np_utils import to_categorical
for epoch in range(1000):
    loss = 0.
    for x, y in batch_data(charints, BATCH_SIZE, SEQ_LENGTH):
        y_cat = to_categorical(y, V+1)
        l = model.train_on_batch(x, y_cat)
        loss = loss + l
    if (epoch + 1) % 50 == 0:
        print("Epoch:", epoch)
        print("Loss:", loss)
# Out:
# Epoch: 49
# Loss: 12.101264357566833
# Epoch: 99
# Loss: 12.013091564178467
# Epoch: 149
# Loss: 11.97203528881073
# Epoch: 199
# Loss: 11.99597692489624
# Epoch: 249
# Loss: 11.894448041915894
# Epoch: 299
# Loss: 12.32767653465271
# Epoch: 349
# Loss: 11.924075961112976
# Epoch: 399
# Loss: 11.944156289100647
# Epoch: 449
# Loss: 11.887133836746216
# Epoch: 499
# Loss: 12.316861391067505
# Epoch: 549
# Loss: 11.890361428260803
# Epoch: 599
# Loss: 12.400230646133423
# Epoch: 649
# Loss: 11.865722894668579
# Epoch: 699
# Loss: 12.208091020584106
# Epoch: 749
# Loss: 11.810593366622925
# Epoch: 799
# Loss: 12.085095167160034
# Epoch: 849
# Loss: 11.798312187194824
# Epoch: 899
# Loss: 11.749712109565735
# Epoch: 949
# Loss: 11.765508532524109
# Epoch: 999
# Loss: 11.946038365364075

# %%
PRE_BATCH_SIZE = 1
# 使用 keras 建立一個非常簡單的 LSTM 模型
infer = Sequential()
# 詞嵌入層
# 將每個索引數字對應到一個高維空間的向量
infer.add(Embedding(input_dim=V+1, 
                    mask_zero=True,
                    output_dim=EMBEDDING_DIM, 
                    batch_input_shape=(PRE_BATCH_SIZE, None)))

# LSTM 層
# 負責將序列數據依序讀入並做處理
infer.add(LSTM(units=RNN_UNITS, 
               return_sequences=True, 
               stateful=True))

# 全連接層
# 負責 model 每個中文字出現的可能性
infer.add(Dense(V+1, activation="softmax"))
infer.summary()
infer.set_weights(model.get_weights())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (1, None, 128)            335360
# _________________________________________________________________
# lstm_6 (LSTM)                (1, None, 64)             49408
# _________________________________________________________________
# dense_6 (Dense)              (1, None, 2621)           170365
# =================================================================
# Total params: 555,133
# Trainable params: 555,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
import textwrap

sampled = [word_to_index["張"]]
for _ in range(512):
    if len(sampled) == 0:
        batch = np.zeros((1, 1))
        c = np.random.randint(1, V+1)
        batch[0, 0] = c
        print("起始字:", index_to_word[c])   
        sampled.append(c)
    else:
        batch = np.zeros((1, 1))
        batch[0, 0] = sampled[-1]
    result = infer.predict_on_batch(batch).ravel()
    sample = np.random.choice(list(range(V+1)), p=result)
    sampled.append(sample)
    
article = "".join([index_to_word[c] for c in sampled])
print("\n".join(textwrap.wrap(article, 30)))
# Out:
# 張翠山正共有了個巨鯨船姑娘中划碧瓦，毒鹽真人，睜心料勢奇變，
# 張翠山斜身過，蘆堤之來，刷猛子一晃，百千兩馬邁義之上，鐵瓜虎
# 頭始終兀自覺青驢一紅。紅臉病由望這鷹是個仆役，否見這個下子叫
# 甚么好好，我別張詩發下加上的桌下，雖是一掌便須使的一聲，臂上
# 看給他气倒。兩人抱了鏢師，過了他身上了一頓，一動也不動得來，
# 竟不能恭這位殷們僧人只是老者插著節字，伸手向著那對鐵鑄羅漢遞
# 有迅速，漸漸和青驢臀下，一生妄首我上武當派下的神一能學當、無
# 學，都總是哪一位？”郭襄笑道：“這……郭是是誰？”毒鏢看适才
# 說過了几句。郭襄拱手是歎禮，這時心想是江，他們那少女道：“我
# 三年的他佛的天下，便要出去要彈著每一場浩劫。”那番寺中酸痛：
# “遲于蛇蝎請援片一壽卻均寺武學拳法，卻听尋這一局里霧力大師。
# 師父和白袍客心頭頸中漸格腳鉤，右手撤劍，身命的使勁，當的說完
# ，只是卻能必貽么酒。”張翠山搖頭道：“這三位壇主干人長嘯相，
# 張君寶，雙眼中的一聲，冷笑道：“羅漢堂，領神態系。我要進襲，
# 雙方好，便想于是一張便是江湖上少林便在意。” 　　張翠山見你
# 諸弟，那人怎樣？給了這時后心甚快，料想真好得半點不許女流和旁
# 人，想起哪里的他們交出短劍。”張君寶歎道：“后面留前終王爺，
# 且耐煩

# %%
sentence = "少林寺"
sampled = list([word_to_index[c] for c in sentence if c in word_to_index])
batch = np.zeros((1, 1))
for i in sampled:
    batch[0, 0] = i
    infer.predict_on_batch(batch)

for _ in range(512):
    batch[0, 0] = sampled[-1]
    result = infer.predict_on_batch(batch).ravel()
    sample = np.random.choice(list(range(V+1)), p=result)
    sampled.append(sample)
    
article = "".join([index_to_word[c] for c in sampled])
print("\n".join(textwrap.wrap(article, 30)))
# Out:
# 少林寺的老僧。對少林中一齊搶上前她叫气，喝道：“殷姑娘鏢局的
# 小流自己縫補樊，竟精如鏡迎下內力以衣衫射繡著一陣蓋。緩緩搖指
# 連點。人听見三人說道：“我要仔仔壯士白色文色間的扭起出。較气
# 躁，伸手必定，一震之后，只見圓圈是兩步，是當、大的鏢局東邪。
# ”這時淮水清俠，擅自如一撞，登時便如坐舟而來。覺遠大肩而行，
# 輕輕巧巧的一筆一起。禪師一個暗器上去，說道：“你師兄！”郭襄
# 和頭急、收在毒紅’，玄武當七俠多人的第二十年間的他老的一個劇
# 盜，卻是少林寺也是一划多時，反而旗。張翠山更精興便不作“你”
# 字，第三出茅廬的道雅心細看，未見么？”他叫話。
# 　　宋遠橋道：“好好家來的精行怖，掌中勁風颯然。 　　俞岱岩
# 心中一凜，見張翠山走過。廟中張翠山走進廳上，忽听得前后一一拳
# 的躲一被，同時鼓戰無息，說道：“大家不要追急。俞岱岩心頭怦怦
# 怦怦怦逼一答話亂松水，喀喇喇制，身材同蜡作口寂，臉上微微一動
# ，已是瞧著他“闖少林”她之處，乃是“天當傳禮。”當下滿腔怒，
# 听得他們問甚么‘各般事端原，遠局中青驢小子高應一閃，向外的武
# 功，同時被蚊漫密密。勢愈物，開開來在流面皆清楚。潘天耕，張翠
# 山接著便到左手將攻口中第三月。郭襄動勁斷了一頓，何足道有气。
# 又是另有人人，怎么不用
